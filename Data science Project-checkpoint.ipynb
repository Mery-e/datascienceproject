# %% [markdown]
# # Part 1: Data Collection for Text Comparison and Clustering
#
# ## Data Collection

# %%
import wikipedia
import requests
from bs4 import BeautifulSoup
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
from urllib.parse import quote
from typing import List, Dict, Tuple
import requests
import json
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import spacy
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from collections import Counter
import numpy as np
 
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/meryem/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/meryem/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
categories = [("Astronauts", "dbo:Astronaut"), ("Chefs", "dbo:Chef")]
max_biographies_per_category = 100
max_biographies = 100

# %% [markdown]
# **1.1 Extracting Biographies**

# %%
def get_bibliography(category: str, rdf_type: str, max_biographies: int ) -> List[str]:
    """
    Retrieve biographies from Wikipedia for a specified category and RDF type.

    Args:
        category (str): The category name (e.g., "Astronauts", "Chefs").
        rdf_type (str): The RDF type of the category (e.g., "dbo:Astronaut", "dbo:Chef").
        max_biographies (int): Maximum number of biographies to collect (default: 100).

    Returns:
        List[str]: A list of biographies extracted from Wikipedia.
    """
    biographies = []
    
    encoded_category = quote(category)  # Encode the category name for use in the SPARQL query
    
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    query = f"""
        PREFIX dbo: <http://dbpedia.org/ontology/>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

        SELECT DISTINCT ?page ?summary
        WHERE {{
            # ?page rdf:type {rdf_type} .
            # ?page rdfs:label ?label .
            # ?page dbo:abstract ?summary .
            FILTER (LANG(?label) = 'en') .
            FILTER (LANG(?summary) = 'en') .
        }}
        LIMIT {max_biographies}
    """
    
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    results = sparql.query().convert()
    
    for result in results["results"]["bindings"]:
        biography = result["summary"]["value"]
        biographies.append(biography)
    
    return biographies

# %% [markdown]
# **1.2 Extracting Knowledge Graph Facts**

# %%
def extract_kg_facts(person_names: List[str]) -> Dict[str, List[Dict]]:
    """
    Extract KG Graph facts (RDF triples) for the specified people from DBpedia.

    Args:
        person_names (List[str]): List of person names.

    Returns:
        Dict[str, List[Dict]]: A dictionary containing KG Graph facts for each person.
    """
    kg_facts = {}

    for person_name in person_names:
        kg_facts[person_name] = []

        sparql = SPARQLWrapper("http://dbpedia.org/sparql")
        encoded_person_name = quote(person_name)
        query = f"""
            PREFIX dbo: <http://dbpedia.org/ontology/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            SELECT DISTINCT ?predicate ?object
            WHERE {{
                <http://dbpedia.org/resource/{encoded_person_name}> ?predicate ?object.
                FILTER (strstarts(str(?predicate), str(dbo:)))
            }}
        """

        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)

        results = sparql.query().convert()

        for result in results["results"]["bindings"]:
            predicate = result["predicate"]["value"]
            obj = result["object"]["value"]
            kg_facts[person_name].append({"predicate": predicate, "object": obj})

    return kg_facts

# %%
def get_bibliography_and_kg_facts(categories: List[Tuple[str, str]], max_biographies: int = 100) -> Dict[str, Dict[str, List[Dict]]]:
    """
    Retrieve biographies from Wikipedia for specified categories and their RDF types,
    and extract KG Graph facts (RDF triples) for each person mentioned in the biographies.

    Args:
        categories (List[Tuple[str, str]]): List of tuples containing category name and RDF type.
        max_biographies (int): Maximum number of biographies to collect for each category (default: 100).

    Returns:
        Dict[str, Dict[str, List[Dict]]]: A dictionary containing biographies and KG Graph facts for each category.
    """
    data = {}

    for category, rdf_type in categories:
        biographies = get_bibliography(category, rdf_type, max_biographies=max_biographies)
        person_names = [biography.split()[0] for biography in biographies]  # Extract person names from biographies
        kg_facts = extract_kg_facts(person_names)
        data[category] = {"biographies": biographies, "kg_facts": kg_facts}

    return data

# %%
data = {}

for category, rdf_type in categories:
    biographies_and_facts = get_bibliography_and_kg_facts([(category, rdf_type)], max_biographies=max_biographies_per_category)
    data[category] = biographies_and_facts[category]

for category, category_data in data.items():
    print(f"Category: {category}")
    print("Biographies:")
    for idx, biography in enumerate(category_data["biographies"][:5]):
        print(f"{idx + 1}. {biography}")
    print("KG Facts:")
    for person, facts in category_data["kg_facts"].items():
        print(f"KG Facts for {person}:")
        for fact in facts:
            print(f"- {fact['predicate']}: {fact['object']}")
# Out:
# Category: Astronauts
# Biographies:
# 1. Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a Chinese People's Liberation Army Astronaut Corps (PLAAC) taikonaut selected as part of the Shenzhou program.
# 2. Carl Erwin Walz (Colonel, USAF, Ret.) (born 6 September 1955) is a retired NASA astronaut currently working for Orbital Sciences Corporation's Advanced Programs Group as vice president for Human Space Flight Operations. Walz was formerly assigned to the Exploration Systems Mission Directorate at NASA Headquarters in Washington, D.C. He was the Acting Director for the Advanced Capabilities Division in the Exploration Systems Mission Directorate, and was responsible for a broad range of activities to include Human Research, Technology Development, Nuclear Power and Propulsion and the Lunar Robotic Exploration Programs to support the Vision for Space Exploration.
# 3. Carl Joseph Meade (born November 16, 1950) is a former NASA astronaut.
# 4. Carlos Ismael Noriega (born 8 October 1959) is a Peruvian-American NASA employee, a former NASA astronaut and a retired U.S. Marine Corps lieutenant colonel.
# 5. Pyotr Valerievich Dubrov (Russian: Пётр Валерьевич Дубров; born 30 January 1978) is a Russian engineer and cosmonaut selected by Roscosmos in 2012.
# KG Facts:
# KG Facts for Cai:
# - http://dbpedia.org/ontology/wikiPageID: 2737076
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1072677844
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Cai_(state)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Cai_(surname)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Cairo_International_Airport
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Caithness
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Canadian_Airlines_International
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carbonic_anhydrase_inhibitor
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Mesoamerican_languages
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Cái_River
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/CAIS_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Kai_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/College_of_Anaesthesiologists_of_Ireland
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Community_Associations_Institute
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Club_Alpino_Italiano
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Club_Atlético_Independiente
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Coleraine_Academical_Institution
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Conodont_Alteration_Index
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Corendon_Airlines
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Corpo_Aereo_Italiano
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Comisión_de_Actividades_Infantiles
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Comprehensive_Agreement_on_Investment
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Computer-aided_inspection
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Computer-assisted_language_learning
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Caí_River
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/WCAI
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Central_Asia_Institute
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Chartered_Accountants_Ireland
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Codon_Adaptation_Index
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Cold_air_intake
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/ISO_639-2
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Christian_Assemblies_International
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Calcium-aluminium-rich_inclusion
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Cai_(name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Capitol_Archaeological_Institute
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Club_Atletico_Independiente_de_La_Chorrera
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Compagnia_Aerea_Italiana
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Computer_assisted_instruction
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Controlled_Auto-Ignition
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/ISO_639-5
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Sir_Kay
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Cai_(state)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Cai_(surname)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Cairo_International_Airport
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Caithness
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Canadian_Airlines_International
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carbonic_anhydrase_inhibitor
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/CAIS_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/College_of_Anaesthesiologists_of_Ireland
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Community_Associations_Institute
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Club_Alpino_Italiano
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Club_Atlético_Independiente
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Coleraine_Academical_Institution
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Conodont_Alteration_Index
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Corpo_Aereo_Italiano
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Comisión_de_Actividades_Infantiles
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Comprehensive_Agreement_on_Investment
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Computer-aided_inspection
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/WCAI
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Central_Asia_Institute
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Chartered_Accountants_Ireland
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Codon_Adaptation_Index
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Cold_air_intake
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Christian_Assemblies_International
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Calcium-aluminium-rich_inclusion
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Cai_(name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Capitol_Archaeological_Institute
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Club_Atletico_Independiente_de_La_Chorrera
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Compagnia_Aerea_Italiana
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Computer_assisted_instruction
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Controlled_Auto-Ignition
# - http://dbpedia.org/ontology/abstract: Zkratka CAI může mít více významů:
# * Corendon Airlines – turecká letecká společnost
# * Corpo Aereo Italiano – Italský letecký sbor vyslaný Itálií do bitvy o Británii
# * – Italský alpinistický klub
# * Oficiální zkratka IATA pro Mezinárodní letiště KáhiraTato stránka je rozcestník (tj. místo s odkazy na články, které by jinak měly stejný název) obsahující různé významy tříznakových kombinací. Pokud vás sem dovedl nějaký odkaz, který by měl správně směřovat na specifický význam této kombinace znaků, můžete Wikipedii pomoci tím, že se vrátíte na odkazující stránku a opravíte tam odkaz tak, aby vedl přímo na odpovídající konkrétní článek. V případě, že si nejste jisti, přidejte prosím stránku na seznam.
# - http://dbpedia.org/ontology/wikiPageLength: 2715
# KG Facts for Carl:
# - http://dbpedia.org/ontology/wikiPageID: 1289837
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1097493952
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Canadian_Association_of_Research_Libraries
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carl,_Georgia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carl,_West_Virginia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carl_(name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carleton_College
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carl²
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/List_of_Aqua_Teen_Hunger_Force_episodes
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Colorado_Alliance_of_Research_Libraries
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carle
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carle_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Charles
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Karle_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Karl_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Canadian_Association_of_Research_Libraries
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carl,_Georgia
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carl,_West_Virginia
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carl_(name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carleton_College
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carl²
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Colorado_Alliance_of_Research_Libraries
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carle
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carle_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Charles
# - http://dbpedia.org/ontology/wikiPageInterLanguageLink: http://ja.dbpedia.org/resource/カール
# - http://dbpedia.org/ontology/wikiPageInterLanguageLink: http://zh.dbpedia.org/resource/卡尔
# - http://dbpedia.org/ontology/wikiPageLength: 718
# KG Facts for Carlos:
# - http://dbpedia.org/ontology/wikiPageID: 32786380
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1111887490
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos,_Indiana
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos,_Maryland
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos,_Minnesota
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos,_West_Virginia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(Calusa)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(DJ)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(cycling_team)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(footballer,_born_1985)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(footballer,_born_1995)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(miniseries)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(singer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_the_Jackal
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Don_Carlos_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Karlos_(name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlo_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos,_Alberta
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(surname)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(Timorese_footballer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(album)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carlos_(crater)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos,_Indiana
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos,_Maryland
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos,_Minnesota
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos,_West_Virginia
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(Calusa)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(DJ)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(cycling_team)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(footballer,_born_1985)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(footballer,_born_1995)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(miniseries)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(singer)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_the_Jackal
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Don_Carlos_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos,_Alberta
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(given_name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(surname)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(Timorese_footballer)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(album)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Carlos_(crater)
# - http://dbpedia.org/ontology/abstract: カルロス（Carlos）は、カール大帝（カロルス大帝、Carolus Magnus）に因むスペイン語、ポルトガル語の人名である。同じ綴りでカーロスと読まれることもある。 フランス語のシャルル、イタリア語のカルロ、ドイツ語・スウェーデン語・ノルウェー語のカール、英語のチャールズも参照のこと。
# - http://dbpedia.org/ontology/wikiPageLength: 1504
# KG Facts for Pyotr:
# - http://dbpedia.org/ontology/wikiPageID: 3741748
# - http://dbpedia.org/ontology/wikiPageRevisionID: 618803199
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Peter_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Category:Russian_masculine_given_names
# - http://dbpedia.org/ontology/wikiPageRedirects: http://dbpedia.org/resource/Peter_(given_name)
# - http://dbpedia.org/ontology/wikiPageLength: 75
# KG Facts for Robert:
# - http://dbpedia.org/ontology/wikiPageID: 915493
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1124012698
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Caesium
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/California_State_Senate
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Canadian_Space_Agency
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Cannibal_Corpse
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Carl_Robert_Jakobson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/President_of_the_Swiss_Confederation
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prime_Minister_of_Australia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prime_Minister_of_France
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prime_Minister_of_Great_Britain
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prime_Minister_of_New_Zealand
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prime_Minister_of_Slovakia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prime_Minister_of_Sweden
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prime_Minister_of_the_United_Kingdom
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prime_minister_of_Canada
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prince_Robert,_Duke_of_Chartres
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Privateer
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Provisional_Irish_Republican_Army
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Puck_(folklore)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Ballistic_missiles
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Liston
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Lopez
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Louis_Stevenson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Lowry_(governor)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_M._La_Follette
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_M._La_Follette_Jr.
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_M._Lightfoot_Jr.
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_M._Price
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_M._Shoemaker
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_M._T._Hunter
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mansell
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Marcellus_Stewart
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mark_Edwards
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Maudsley
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_McClure
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_McDade
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_McGowan_Littlejohn
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_McKimson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_McNamara
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Menzies
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Miles
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Miller_Montague
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mitchum
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Molyneux
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Monckton
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Montgomery_(actor)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Moray
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Morgenthau
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Morris_(financier)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mueller
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mugabe
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mulka
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mulligan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mühren
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_N._Adams
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Nairac
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Napper
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Neller
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Nivelle
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Nozick
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_O'Hara_Burke
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_O._Scholz
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_O._Tyler
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Olds
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Oppenheimer
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_P._Patterson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Palmer_(singer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Paston,_1st_Earl_of_Yarmouth
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Patrick
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Patterson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Pattinson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Peary
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Peel
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Person
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Peverell_Hichens
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Pickton
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Plant
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_R._Livingston_(chancellor)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Redford
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Reid,_1st_Earl_Loreburn
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Rheault
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Rich,_2nd_Earl_of_Warwick
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Ritter
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Ritter_von_Greim
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Roddam
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Rodriguez
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Rogers_(British_Army_officer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Rolfe,_1st_Baron_Cranworth
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Rollo_Gillespie
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Roosevelt
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Ross_(British_Army_officer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Rozhdestvensky
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Ryan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_S._Beightler
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_S._Kerr
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_S._Kerr_III
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_S._Kimbrough
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Sale
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Satcher
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Schuman
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Schumann
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Schwentke
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Seldon_Lady
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Serber
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Shapiro_(chemist)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Shea
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Sheehan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Shelton_(Ku_Klux_Klan)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Sink
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Smalls
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Smigel
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Smith_(Cabinet_member)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Smith_(musician)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Sobukwe
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Stanford_Tuck
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Stewart,_1st_Marquess_of_Londonderry
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Stewart,_Viscount_Castlereagh
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Stockton_Green
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Stopford_(Royal_Navy_officer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Stout
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Stromberg
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Stroud
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Sturges
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Swan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_T._Barrett
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_T._Conrad
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Taylor_(American_actor)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Tepper
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Themptander
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Thirsk
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Tilton
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Todd_Lincoln
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Toombs
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Treat
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Treat_Paine
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Trimbole
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Trujillo
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Trump
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Vaughn
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Viren
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_W._Porter_Jr.
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_W._Service
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_W._Wood
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wadlow
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wagner
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Walker_(actor,_born_1918)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Walpole
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Walpole,_2nd_Earl_of_Orford
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wayne_Danielson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wayne_Harris
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wesley_Knighton
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Whittaker_(British_Army_officer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Whittaker_(fighter)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wickens
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wiene
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_William_Fisher
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Windsor-Clive,_1st_Earl_of_Plymouth
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Winston
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Winthrop_(banker)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wipper
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Wise
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Worth_Bingham
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Yellowtail
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Young_(actor)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Zemeckis
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_de_Craon
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_de_Montesquiou
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_of_Bellême,_3rd_Earl_of_Shrewsbury
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_of_Molesme
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_the_Bruce
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Baggio
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Carlos
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Carlos_(singer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Draghetti
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Farinacci
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_López_Ufarte
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Mancini
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Mangabeira_Unger
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_María_Ortiz
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Matta
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Micheletti
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Sánchez_Vilella
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberto_Vittori
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robin_(name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robin_Hood
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robin_Olds
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robinson_(name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robotics
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rock_and_Roll_Hall_of_Fame
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rocket
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rocky_Balboa
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roger
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rogers'_Rangers
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rogue_River_Wars
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roland_(name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Romanian_language
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roparz_Hemon
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roy_Urquhart
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Royal_Air_Force
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Royal_Society
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rubidium
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rudolph_(name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Samurai_Jack
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/San_Francisco_Chronicle
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Satan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Schellenberg_smuggling_incident
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Scots_language
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Scottish_Gaelic
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/List_of_ambassadors_of_the_United_States_to_the_United_Kingdom
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/List_of_colonial_governors_of_Virginia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Mirabal
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Prison_warden
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/John_F._Kennedy_Space_Center
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/2009_Honduran_coup_d'état
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Battle_of_Bannockburn
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Battle_of_Halidon_Hill
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bengal
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bert_Nievera
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Beto_O'Rourke
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Beyblade_(manga)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Big_Hero_6_(film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Black_Hawk_War
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Black_Sabbath
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Blues
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Bergen
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Chapek
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Chilcott
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Crosby
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Dole
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Dylan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Hawke
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Iger
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Kalsu
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Kane
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Marley
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_McNamara_(baseball)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Moir
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Moses_(activist)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Peck
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Ross
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Seger
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Turner_(New_York_politician)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Weir
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_Wiseman
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bob_the_Builder
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bobby_Darin
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bobby_Hackett
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bobby_Hull
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bobby_Joe_Long
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bobby_McFerrin
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bobby_Nash
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bobby_Orr
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bobby_Vee
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bolshevik
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Boris_III_of_Bulgaria
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Breton_language
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brigham_Young_University
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Dead_&_Company
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Deadpool
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Death_of_Robert_Stevens
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Defense_Intelligence_Agency
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Demon
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Despicable_Me
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Homeward_Bound:_The_Incredible_Journey
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Honduras
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/House_of_Bellême
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Household_deity
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Hulk
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Hungarian_language
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Judas_Priest
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/List_of_Governors_of_California_before_1850
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/List_of_chief_music_critics
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Peelite
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Reich_Ministry_of_Food_and_Agriculture
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Resident_Evil
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rex_Romanorum
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rhode_Island
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Barrett
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Bell
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Benedict
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Bourdon
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Conway
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Ford
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Halford
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Hyman
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Kardashian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Letterman
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Liefeld
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Lowe
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Marshall
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Minkoff
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Roy_MacGregor
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Scallon
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Swire
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Terry
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Rob_Zombie
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robbie_Amell
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robbie_Coltrane
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robbie_Kerr
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robbie_Rotten
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robbie_Williams
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robby_Krieger
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Roberrt
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert-Richard_Zapp
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_A._Frosch
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_A._Green
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_A._Heinlein
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_A._Lewis
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_A._Little
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_A._Lovett
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_A._Parker
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_A._Taft
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Abela
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Abercromby_of_Airthrey
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Alexander_(Irish_sportsman)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Altman
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Anderson_(murderer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Andrews_Millikan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Anthony_Buell
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Anton_Wilson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_B._Abrams
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_B._Johnston
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_B._Weide
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Baden-Powell,_1st_Baron_Baden-Powell
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Bales
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Ballard
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Bartels
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Bartlett_(explorer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Robert_Bellarmine
# ...
# - http://dbpedia.org/ontology/wikiPageLength: 2508
# KG Facts for Patrick:
# - http://dbpedia.org/ontology/wikiPageID: 12838538
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1118498372
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patric_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick,_Queensland
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick,_South_Carolina
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(1978_film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(2013_film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(2018_film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(2019_film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_1983)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_1985)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_1992)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_1994)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_2000)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_May_1998)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_November_1998)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(parish)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(sportswear_company)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Don_Harris_(wrestler)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Croagh_Patrick
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Saint_Patrick
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Partick_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick,_1st_Earl_of_Salisbury
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(surname)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_Corporation
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_County,_Virginia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_Division
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Gilla_Pátraic
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/John_Byrne_(Scottish_playwright)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick,_Queensland
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick,_South_Carolina
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(1978_film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(2013_film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(2018_film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(2019_film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_1983)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_1985)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_1992)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_1994)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_2000)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_May_1998)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_November_1998)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(given_name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(parish)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(sportswear_company)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Croagh_Patrick
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Saint_Patrick
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick,_1st_Earl_of_Salisbury
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(surname)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_Corporation
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_County,_Virginia
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_Division
# - http://dbpedia.org/ontology/wikiPageInterLanguageLink: http://ja.dbpedia.org/resource/パトリック
# - http://dbpedia.org/ontology/wikiPageLength: 1955
# KG Facts for Paul:
# - http://dbpedia.org/ontology/wikiPageID: 24092
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1121143173
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Little_Witch_Academia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Alabama
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Cape_Verde
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Cornwall
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Idaho
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(American_Horror_Story)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Nestorian_patriarch)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(PJ_Morton_album)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Pokémon)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Ponomaryov)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(bakery)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_I_of_Russia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_McCartney
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_Stookey
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_of_Greece
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_the_Apostle
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_the_Deacon
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paulus_Catena
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Portable_Aqua_Unit_for_Lifesaving
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Păuleasca_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Păuleni_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Păulești_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_the_Octopus
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Lucius_Aemilius_Paullus_Macedonicus
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Sir_Walter_Scott
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Nebraska
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_son_of_Peter
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Life_with_Derek)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Meletiev)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(bishop_of_Mérida)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(civil_parish)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(exarch)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(father_of_Maurice)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(nursery)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(play)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(singer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(song)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(surname)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_Clarke_(character)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_II_(octopus)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_of_Aegina
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paula_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paulus_Alexandrinus
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Pope_Paul_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Saint_Paul_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/The_Paul
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Julius_Paulus_Prudentissimus
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Aichi_E16A
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/DNA_Productions
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/The_Beatles
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Hurricane_Paul_(1982)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Hurricane_Paul_(2006)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Poker_Face_Paul
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/St._Paul_(oratorio)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Alabama
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Cape_Verde
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Cornwall
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Idaho
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(American_Horror_Story)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Nestorian_patriarch)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(PJ_Morton_album)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Pokémon)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Ponomaryov)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(bakery)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(given_name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_I_of_Russia
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_McCartney
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_Stookey
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_of_Greece
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_the_Apostle
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_the_Deacon
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paulus_Catena
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Portable_Aqua_Unit_for_Lifesaving
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_the_Octopus
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Lucius_Aemilius_Paullus_Macedonicus
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Nebraska
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_son_of_Peter
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Life_with_Derek)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Meletiev)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(bishop_of_Mérida)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(civil_parish)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(exarch)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(father_of_Maurice)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(nursery)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(play)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(singer)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(song)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(surname)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_Clarke_(character)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_II_(octopus)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_of_Aegina
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paula_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paulus_Alexandrinus
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Pope_Paul_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Saint_Paul_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/The_Paul
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Julius_Paulus_Prudentissimus
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Hurricane_Paul_(1982)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Hurricane_Paul_(2006)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Poker_Face_Paul
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/St._Paul_(oratorio)
# - http://dbpedia.org/ontology/wikiPageLength: 4363

# %% [markdown]
#    **1.3 Storing Data**
#    - Biographies will be stored in a Pandas DataFrame, where each row represents a biography and its associated category.
#    - Each biography will also be saved in a separate text file named **`person_category.txt`**.

# %%
def store_biographies_as_dataframe(categories: List[Tuple[str, str]], max_biographies: int) -> pd.DataFrame:
    """
    Store each biography along with its category in a Pandas DataFrame.

    Args:
        categories (List[Tuple[str, str]]): List of tuples containing category names and RDF types.
        max_biographies (int): Maximum number of biographies to collect.

    Returns:
        pd.DataFrame: DataFrame containing biographies and categories.
    """
    biographies_list = []
    categories_list = []
    
    for category, rdf_type in categories:
        biographies = get_bibliography(category, rdf_type, max_biographies)
        biographies_list.extend(biographies)
        categories_list.extend([category] * len(biographies))

    # Create DataFrame
    df = pd.DataFrame({"Biography": biographies_list, "Category": categories_list})
    return df

# %%
df = store_biographies_as_dataframe(categories, max_biographies)
df
# Out:
#                                              Biography    Category
# 0    Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a C...  Astronauts
# 1    Carl Erwin Walz (Colonel, USAF, Ret.) (born 6 ...  Astronauts
# 2    Carl Joseph Meade (born November 16, 1950) is ...  Astronauts
# 3    Carlos Ismael Noriega (born 8 October 1959) is...  Astronauts
# 4    Pyotr Valerievich Dubrov (Russian: Пётр Валерь...  Astronauts
# ..                                                 ...         ...
# 195  Julien Royer (born 1 September 1982) is a Fren...       Chefs
# 196  Juliet Corson (January 14, 1841 – June 18, 189...       Chefs
# 197  Beverly Kim is a James Beard Award-winning che...       Chefs
# 198  Patrick O’Connell is the chef and proprietor o...       Chefs
# 199  Paul Ainsworth (born 1979) is a British chef f...       Chefs
#
# [200 rows x 2 columns]

# %%
def store_biographies_as_text_files(categories: List[Tuple[str, str]], max_biographies: int):
    """
    Store each biography in a separate text file named person_category.txt.

    Args:
        categories (List[Tuple[str, str]]): List of tuples containing category names and RDF types.
        max_biographies (int): Maximum number of biographies to collect.
    """
    for category, rdf_type in categories:
        biographies = get_bibliography(category, rdf_type, max_biographies)
        for biography in biographies:
            # Store biography in a text file named person_category.txt
            file_name = f"{biography[:20]}_{category.replace(' ', '_')}.txt"
            with open(file_name, "w") as file:
                file.write(biography)
            print(f"File '{file_name}' created successfully.")

# %%
store_biographies_as_text_files(categories, max_biographies)
# Out:
# File 'Cai Xuzhe (Chinese: _Astronauts.txt' created successfully.
# File 'Carl Erwin Walz (Col_Astronauts.txt' created successfully.
# File 'Carl Joseph Meade (b_Astronauts.txt' created successfully.
# File 'Carlos Ismael Norieg_Astronauts.txt' created successfully.
# File 'Pyotr Valerievich Du_Astronauts.txt' created successfully.
# File 'Pyotr Ilyich Klimuk _Astronauts.txt' created successfully.
# File 'Pyotr Ivanovich Kolo_Astronauts.txt' created successfully.
# File 'Robert Michael "Bob"_Astronauts.txt' created successfully.
# File 'Robert Lee "Bobby" S_Astronauts.txt' created successfully.
# File 'Robert Brent "Bob" T_Astronauts.txt' created successfully.
# File 'Roberta Lynn Bondar _Astronauts.txt' created successfully.
# File 'Brigadier Roberto Vi_Astronauts.txt' created successfully.
# File 'Rodolfo Neri Vela (b_Astronauts.txt' created successfully.
# File 'Roger Bruce Chaffee _Astronauts.txt' created successfully.
# File 'Roger Keith Crouch (_Astronauts.txt' created successfully.
# File 'Roger E. Kanet (born_Astronauts.txt' created successfully.
# File 'Roman Yurievich Roma_Astronauts.txt' created successfully.
# File 'Ronald Ellwin Evans _Astronauts.txt' created successfully.
# File 'Ronald John Garan Jr_Astronauts.txt' created successfully.
# File 'Ronald John Grabe (b_Astronauts.txt' created successfully.
# File 'Ronald "Ron" Michael_Astronauts.txt' created successfully.
# File 'Ronald Erwin McNair _Astronauts.txt' created successfully.
# File 'Ronald Anthony Paris_Astronauts.txt' created successfully.
# File 'Samantha Cristoforet_Astronauts.txt' created successfully.
# File 'Samuel Thornton Durr_Astronauts.txt' created successfully.
# File 'Sandra Hall Magnus (_Astronauts.txt' created successfully.
# File 'Sarah Gillis is an A_Astronauts.txt' created successfully.
# File 'Satoshi Furukawa (古川_Astronauts.txt' created successfully.
# File 'Scott Douglas "Scoot_Astronauts.txt' created successfully.
# File 'Malcolm Scott Carpen_Astronauts.txt' created successfully.
# File 'Scott David Tingle (_Astronauts.txt' created successfully.
# File 'Scott Edward Parazyn_Astronauts.txt' created successfully.
# File 'Scott Jay "Doc" Horo_Astronauts.txt' created successfully.
# File 'Scott Joseph Kelly (_Astronauts.txt' created successfully.
# File 'Barry Eugene "Butch"_Astronauts.txt' created successfully.
# File 'Bernard Anthony Harr_Astronauts.txt' created successfully.
# File 'Bertram Raoul Bulkin_Astronauts.txt' created successfully.
# File 'Bertalan Farkas (bor_Astronauts.txt' created successfully.
# File 'William Barton Bridg_Astronauts.txt' created successfully.
# File 'Bjarni Valdimar Tryg_Astronauts.txt' created successfully.
# File 'Robert Louis Behnken_Astronauts.txt' created successfully.
# File 'Bonnie Jeanne Dunbar_Astronauts.txt' created successfully.
# File 'Boris Dmitriyevich A_Astronauts.txt' created successfully.
# File 'Boris Vladimirovich _Astronauts.txt' created successfully.
# File 'Boris Valentinovich _Astronauts.txt' created successfully.
# File 'Boris Borisovich Yeg_Astronauts.txt' created successfully.
# File 'Brent Ward Jett Jr. _Astronauts.txt' created successfully.
# File 'Brewster Hopkinson S_Astronauts.txt' created successfully.
# File 'William Brian Binnie_Astronauts.txt' created successfully.
# File 'Brian Duffy (born Ju_Astronauts.txt' created successfully.
# File 'Brian Todd O'Leary (_Astronauts.txt' created successfully.
# File 'David Carl Hilmers, _Astronauts.txt' created successfully.
# File 'David Cornell Leestm_Astronauts.txt' created successfully.
# File 'David McDowell Brown_Astronauts.txt' created successfully.
# File 'David Mathieson "Dav_Astronauts.txt' created successfully.
# File 'David Saint-Jacques _Astronauts.txt' created successfully.
# File 'David Randolph Scott_Astronauts.txt' created successfully.
# File 'David Alexander Wolf_Astronauts.txt' created successfully.
# File 'Donald Kent "Deke" S_Astronauts.txt' created successfully.
# File 'Deng Qingming (simpl_Astronauts.txt' created successfully.
# File 'Denis Vladimirovich _Astronauts.txt' created successfully.
# File 'Deniz Melissa Burnha_Astronauts.txt' created successfully.
# File 'Dennis Anthony Tito _Astronauts.txt' created successfully.
# File 'Anna Menon is an Ame_Astronauts.txt' created successfully.
# File 'John Oliver Creighto_Astronauts.txt' created successfully.
# File 'John Sumter Bull (Se_Astronauts.txt' created successfully.
# File 'John Watts Young (Se_Astronauts.txt' created successfully.
# File 'Jon Andrew McBride (_Astronauts.txt' created successfully.
# File 'Joseph Albert Walker_Astronauts.txt' created successfully.
# File 'Joseph Michael "Joe"_Astronauts.txt' created successfully.
# File 'Joseph Percival "Joe_Astronauts.txt' created successfully.
# File 'Joseph Peter Kerwin _Astronauts.txt' created successfully.
# File 'Joseph Richard Tanne_Astronauts.txt' created successfully.
# File 'Josh Aaron Cassada (_Astronauts.txt' created successfully.
# File 'Joshua Kutryk (born _Astronauts.txt' created successfully.
# File 'José Moreno Hernánde_Astronauts.txt' created successfully.
# File 'Judith Arlene Resnik_Astronauts.txt' created successfully.
# File 'Patricia Consolatrix_Astronauts.txt' created successfully.
# File 'Patrick Pierre Roger_Astronauts.txt' created successfully.
# File 'Patrick Graham Forre_Astronauts.txt' created successfully.
# File 'Paul Joseph Weitz (J_Astronauts.txt' created successfully.
# File 'Paul Scott "Paco" Lo_Astronauts.txt' created successfully.
# File 'Paul Desmond Scully-_Astronauts.txt' created successfully.
# File 'Paul William Richard_Astronauts.txt' created successfully.
# File 'Pavel Ivanovich Bely_Astronauts.txt' created successfully.
# File 'Pavel Romanovich Pop_Astronauts.txt' created successfully.
# File 'Pavel Vladimirovich _Astronauts.txt' created successfully.
# File 'Pedro Francisco Duqu_Astronauts.txt' created successfully.
# File 'Peggy Annette Whitso_Astronauts.txt' created successfully.
# File 'Charles "Pete" Conra_Astronauts.txt' created successfully.
# File 'Peter Siebold (born _Astronauts.txt' created successfully.
# File 'Peter Jeffrey Kelsay_Astronauts.txt' created successfully.
# File 'Prof. Dr. Reinhard A_Astronauts.txt' created successfully.
# File 'Reinhold Ewald (born_Astronauts.txt' created successfully.
# File 'Renate Luise Brümmer_Astronauts.txt' created successfully.
# File 'Rex Joseph Walheim (_Astronauts.txt' created successfully.
# File 'Margaret Rhea Seddon_Astronauts.txt' created successfully.
# File 'Richard Alan Searfos_Astronauts.txt' created successfully.
# File 'Richard Earl "Dick" _Astronauts.txt' created successfully.
# File 'Richard Francis Gord_Astronauts.txt' created successfully.
# File 'Carla Hall (born May_Chefs.txt' created successfully.
# File 'Carme Ruscalleda i S_Chefs.txt' created successfully.
# File 'Carrie Nahabedian (b_Chefs.txt' created successfully.
# File 'Carson Gulley (June _Chefs.txt' created successfully.
# File 'Catherine Ann Cora i_Chefs.txt' created successfully.
# File 'Beau MacMillan is an_Chefs.txt' created successfully.
# File 'Priscilla Martel is _Chefs.txt' created successfully.
# File 'Roberto Donna is an _Chefs.txt' created successfully.
# File 'Rochelle Adonis is a_Chefs.txt' created successfully.
# File 'Rahman "Rock" Harper_Chefs.txt' created successfully.
# File 'Roger Vergé (French _Chefs.txt' created successfully.
# File 'Rokusaburo Michiba (_Chefs.txt' created successfully.
# File 'Roland Mesnier (July_Chefs.txt' created successfully.
# File 'French-born chef Rol_Chefs.txt' created successfully.
# File 'Ron Siegel (born 196_Chefs.txt' created successfully.
# File 'Rosemary Jacqueline _Chefs.txt' created successfully.
# File 'Roy Choi (born Febru_Chefs.txt' created successfully.
# File 'Roy Fares (born 16 S_Chefs.txt' created successfully.
# File 'Roy Yamaguchi (born _Chefs.txt' created successfully.
# File 'Kim Hee-Tae (Korean:_Chefs.txt' created successfully.
# File 'Sami Tamimi is a Pal_Chefs.txt' created successfully.
# File 'Samin Nosrat (Persia_Chefs.txt' created successfully.
# File 'Sanjeev Kapoor (born_Chefs.txt' created successfully.
# File 'Sanjyot Keer (born J_Chefs.txt' created successfully.
# File 'Santiago Santamaria _Chefs.txt' created successfully.
# File 'Sara Moulton (born F_Chefs.txt' created successfully.
# File 'Sarah Grueneberg is _Chefs.txt' created successfully.
# File 'Saransh Goila (born _Chefs.txt' created successfully.
# File 'Sarma Melngailis (bo_Chefs.txt' created successfully.
# File 'Satwant Singh "Sat" _Chefs.txt' created successfully.
# File 'Scott Conant (born F_Chefs.txt' created successfully.
# File 'Scott Leibfried (bor_Chefs.txt' created successfully.
# File 'Scott Peacock (born _Chefs.txt' created successfully.
# File 'Elia Aboumrad (born _Chefs.txt' created successfully.
# File 'Enrique Olvera (born_Chefs.txt' created successfully.
# File 'Morgan Murphy is a n_Chefs.txt' created successfully.
# File 'M.S. Krishna Iyer (b_Chefs.txt' created successfully.
# File 'Nawab Mehboob Alam K_Chefs.txt' created successfully.
# File 'Melissa Donovan d'Ar_Chefs.txt' created successfully.
# File 'Omar Allibhoy is a S_Chefs.txt' created successfully.
# File 'Priya Krishna is an _Chefs.txt' created successfully.
# File 'Sarah Kramer is a Ca_Chefs.txt' created successfully.
# File 'Belinda Leong is an _Chefs.txt' created successfully.
# File 'Benjamin O'Donoghue _Chefs.txt' created successfully.
# File 'Ben Pollinger is the_Chefs.txt' created successfully.
# File 'Ben Shewry (born 197_Chefs.txt' created successfully.
# File 'Benedetto D'Epiro (b_Chefs.txt' created successfully.
# File 'Benoît Violier (Fren_Chefs.txt' created successfully.
# File 'Bent Stiansen (born _Chefs.txt' created successfully.
# File 'Bernard Daniel Jacqu_Chefs.txt' created successfully.
# File 'Elizabeth "Betty" R._Chefs.txt' created successfully.
# File 'Biba Caggiano (Octob_Chefs.txt' created successfully.
# File 'Thomas Hylton "Bill"_Chefs.txt' created successfully.
# File 'William Granger is a_Chefs.txt' created successfully.
# File 'Bill Harmsen (June 2_Chefs.txt' created successfully.
# File 'Björn Frantzén (born_Chefs.txt' created successfully.
# File 'Bob Blumer was the c_Chefs.txt' created successfully.
# File 'Robert Earl Deen (bo_Chefs.txt' created successfully.
# File 'Robert William Flay _Chefs.txt' created successfully.
# File 'Pablo Logro, also kn_Chefs.txt' created successfully.
# File 'Brad Farmerie was th_Chefs.txt' created successfully.
# File 'Bradley Ogden is a T_Chefs.txt' created successfully.
# File 'Brian James Turner C_Chefs.txt' created successfully.
# File 'David Bouley (born M_Chefs.txt' created successfully.
# File 'David Carmichael is _Chefs.txt' created successfully.
# File 'David Chang (Korean:_Chefs.txt' created successfully.
# File 'David Kinch (born Ap_Chefs.txt' created successfully.
# File 'David Muñoz Rosillo _Chefs.txt' created successfully.
# File 'David Rocco (born Ju_Chefs.txt' created successfully.
# File 'David Ruggerio (born_Chefs.txt' created successfully.
# File 'William Dean Fearing_Chefs.txt' created successfully.
# File 'Delia Ann Smith CH C_Chefs.txt' created successfully.
# File 'Alfred Portale (born_Chefs.txt' created successfully.
# File 'Andrea Reusing is an_Chefs.txt' created successfully.
# File 'Ann Kim is a James B_Chefs.txt' created successfully.
# File 'Anne Byrn (Nashville_Chefs.txt' created successfully.
# File 'Anne Kearney is an A_Chefs.txt' created successfully.
# File 'Antony J. Ballard is_Chefs.txt' created successfully.
# File 'Holger Stromberg (bo_Chefs.txt' created successfully.
# File 'Homaro "Omar" Cantu _Chefs.txt' created successfully.
# File 'Hubert Keller is a n_Chefs.txt' created successfully.
# File 'Hugh Acheson (born N_Chefs.txt' created successfully.
# File 'Jon Hill (c. 1954) i_Chefs.txt' created successfully.
# File 'Jonnie Boer (born Ja_Chefs.txt' created successfully.
# File 'Jonny Lake is a Cana_Chefs.txt' created successfully.
# File 'Jordi Cruz Mas (born_Chefs.txt' created successfully.
# File 'Jordi Roca i Fontané_Chefs.txt' created successfully.
# File 'Joseph 'JJ' Johnson _Chefs.txt' created successfully.
# File 'Josh Emett is a chef_Chefs.txt' created successfully.
# File 'Joyce Chen (née Liao_Chefs.txt' created successfully.
# File 'Joyce Goldstein (bor_Chefs.txt' created successfully.
# File 'Joël Robuchon (Frenc_Chefs.txt' created successfully.
# File 'Juan Mari Arzak Arra_Chefs.txt' created successfully.
# File 'Judy Joo is a chef a_Chefs.txt' created successfully.
# File 'Julia Carolyn Child _Chefs.txt' created successfully.
# File 'Julien Royer (born 1_Chefs.txt' created successfully.
# File 'Juliet Corson (Janua_Chefs.txt' created successfully.
# File 'Beverly Kim is a Jam_Chefs.txt' created successfully.
# File 'Patrick O’Connell is_Chefs.txt' created successfully.
# File 'Paul Ainsworth (born_Chefs.txt' created successfully.

# %% [markdown]
#    - The knowledge graph facts will be stored in a JSON file, mapped back to each person.

# %%
def store_kg_facts_as_json(kg_facts: Dict[str, List[Dict]], file_path: str):
    """
    Store the knowledge graph facts in a JSON file mapped back to each person.

    Args:
        kg_facts (Dict[str, List[Dict]]): A dictionary containing KG Graph facts for each person.
        file_path (str): Path to the JSON file.
    """
      # Extract KG facts for each person
    person_names = df["Biography"].apply(lambda x: x.split('/')[-1]).tolist()
    kg_facts = extract_kg_facts(person_names)
    print("KG facts extracted successfully.")

    # Store KG facts in a JSON file
    with open("kg_facts.json", "w") as file:
        json.dump(kg_facts, file)
    print("JSON file 'kg_facts.json' created successfully.")

# %%
file_path = "kg_facts.json"
store_kg_facts_as_json(kg_facts , file_path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     925             else:
# --> 926                 response = urlopener(request)
#     927             return response, self.returnFormat
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#
# HTTPError: HTTP Error 414: Request-URI Too Large
#
# During handling of the above exception, another exception occurred:
#
# URITooLong                                Traceback (most recent call last)
# /tmp/ipykernel_15026/3696365289.py in <module>
#       1 file_path = "kg_facts.json"
# ----> 2 store_kg_facts_as_json(kg_facts , file_path)
#
# /tmp/ipykernel_15026/3434327277.py in store_kg_facts_as_json(kg_facts, file_path)
#       9       # Extract KG facts for each person
#      10     person_names = df["Biography"].apply(lambda x: x.split('/')[-1]).tolist()
# ---> 11     kg_facts = extract_kg_facts(person_names)
#      12     print("KG facts extracted successfully.")
#      13
#
# /tmp/ipykernel_15026/888724188.py in extract_kg_facts(person_names)
#      29         sparql.setReturnFormat(JSON)
#      30
# ---> 31         results = sparql.query().convert()
#      32
#      33         for result in results["results"]["bindings"]:
#
# ~/.local/lib/python3.10/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#     958         :rtype: :class:`QueryResult` instance
#     959         """
# --> 960         return QueryResult(self._query())
#     961
#     962     def queryAndConvert(self) -> "QueryResult.ConvertResult":
#
# ~/.local/lib/python3.10/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     934                 raise Unauthorized(e.read())
#     935             elif e.code == 414:
# --> 936                 raise URITooLong(e.read())
#     937             elif e.code == 500:
#     938                 raise EndPointInternalError(e.read())
#
# URITooLong: URITooLong: The URI requested by the client is longer than the server is willing to interpret. Check if the request was sent using GET method instead of POST method..
#
# Response:
# b'<html>\r\n<head><title>414 Request-URI Too Large</title></head>\r\n<body>\r\n<center><h1>414 Request-URI Too Large</h1></center>\r\n<hr><center>nginx/1.18.0</center>\r\n</body>\r\n</html>\r\n'

# %% [markdown]
# ## Data Analysis: Text Data

# %% [markdown]
# ### Preprocessing Function (`preprocess_text`):
# 1. Normalize each sentence to lowercase.
# 2. Remove stopwords .
# 3. Join the remaining tokens back into sentences.

# %%
nlp = spacy.load("en_core_web_sm")

# %%
biographies_df = df


def preprocess_text(text):
    doc = nlp(text)  # Tokenize
    sentences = [sent.text for sent in doc.sents]  # Segment into sentences
    return sentences


biographies_df['preprocessed_sentences'] = biographies_df['Biography'].apply(preprocess_text)

def preprocess_tokens(text):
    doc = nlp(text.lower())  # Tokenize and normalize to lowercase
    # Remove stopwords, punctuation, and non-alphabetic tokens
    preprocessed_text = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]
    return preprocessed_text

biographies_df['preprocessed_text'] = biographies_df['Biography'].apply(preprocess_tokens)

# %%
df.head()
# Out:
#                                            Biography    Category  \
# 0  Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a C...  Astronauts
# 1  Carl Erwin Walz (Colonel, USAF, Ret.) (born 6 ...  Astronauts
# 2  Carl Joseph Meade (born November 16, 1950) is ...  Astronauts
# 3  Carlos Ismael Noriega (born 8 October 1959) is...  Astronauts
# 4  Pyotr Valerievich Dubrov (Russian: Пётр Валерь...  Astronauts
#
#                                    preprocessed_text  \
# 0  [cai, xuzhe, chinese, 蔡旭哲, bear, chinese, peop...
# 1  [carl, erwin, walz, colonel, usaf, ret, bear, ...
# 2  [carl, joseph, meade, bear, november, nasa, as...
# 3  [carlos, ismael, noriega, bear, october, peruv...
# 4  [pyotr, valerievich, dubrov, russian, пётр, ва...
#
#                               preprocessed_sentences
# 0  [Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a ...
# 1  [Carl Erwin Walz (Colonel, USAF, Ret.) (born 6...
# 2  [Carl Joseph Meade (born November 16, 1950) is...
# 3  [Carlos Ismael Noriega (born 8 October 1959) i...
# 4  [Pyotr Valerievich Dubrov (Russian: Пётр Валер...

# %%
def get_all_tokens(df, category):
    tokens = []
    for series in df[df["Category"] == category]['preprocessed_text']:
        for t in series:
            tokens.append(t)
    return tokens

# %%
CATEGORY1 = 'Astronauts'
CATEGORY2 = 'Chefs'

# %%
tokens1 = get_all_tokens(df, CATEGORY1)
tokens2 = get_all_tokens(df, CATEGORY2)

# %% [markdown]
# - Vocabulary: 50 most frequent words and word cloud for each category.

# %%
import collections
def make_wordcloud(tokens, n_words):
    data = collections.Counter(tokens).most_common(n_words)
    word_frequencies = {word: freq for word, freq in data}

    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %% [markdown]
# - wordcloud for the category : 'Astronauts'

# %%
make_wordcloud(tokens1, 50)

# %% [markdown]
# - wordcloud for the category : 'Chefs'

# %%
make_wordcloud(tokens2, 50)

# %%
biographies_df['num_sentences'] = biographies_df['preprocessed_sentences'].apply(len)

# %%
df
# Out:
#                                              Biography    Category  \
# 0    Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a C...  Astronauts
# 1    Carl Erwin Walz (Colonel, USAF, Ret.) (born 6 ...  Astronauts
# 2    Carl Joseph Meade (born November 16, 1950) is ...  Astronauts
# 3    Carlos Ismael Noriega (born 8 October 1959) is...  Astronauts
# 4    Pyotr Valerievich Dubrov (Russian: Пётр Валерь...  Astronauts
# ..                                                 ...         ...
# 195  Julien Royer (born 1 September 1982) is a Fren...       Chefs
# 196  Juliet Corson (January 14, 1841 – June 18, 189...       Chefs
# 197  Beverly Kim is a James Beard Award-winning che...       Chefs
# 198  Patrick O’Connell is the chef and proprietor o...       Chefs
# 199  Paul Ainsworth (born 1979) is a British chef f...       Chefs
#
#                                      preprocessed_text  \
# 0    [cai, xuzhe, chinese, 蔡旭哲, bear, chinese, peop...
# 1    [carl, erwin, walz, colonel, usaf, ret, bear, ...
# 2    [carl, joseph, meade, bear, november, nasa, as...
# 3    [carlos, ismael, noriega, bear, october, peruv...
# 4    [pyotr, valerievich, dubrov, russian, пётр, ва...
# ..                                                 ...
# 195  [julien, royer, bear, september, french, chef,...
# 196  [juliet, corson, january, june, leader, cooker...
# 197  [beverly, kim, james, beard, award, win, chef,...
# 198  [patrick, chef, proprietor, inn, little, washi...
# 199  [paul, ainsworth, bear, british, chef, southam...
#
#                                 preprocessed_sentences  num_sentences
# 0    [Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a ...              1
# 1    [Carl Erwin Walz (Colonel, USAF, Ret.) (born 6...              3
# 2    [Carl Joseph Meade (born November 16, 1950) is...              1
# 3    [Carlos Ismael Noriega (born 8 October 1959) i...              1
# 4    [Pyotr Valerievich Dubrov (Russian: Пётр Валер...              1
# ..                                                 ...            ...
# 195  [Julien Royer (born 1 September 1982) is a Fre...              4
# 196  [Juliet Corson (January 14, 1841 – June 18, 18...              2
# 197  [Beverly Kim is a James Beard Award-winning ch...              2
# 198  [Patrick O’Connell is the chef and proprietor ...              1
# 199  [Paul Ainsworth (born 1979) is a British chef ...              3
#
# [200 rows x 5 columns]

# %% [markdown]
# - sum of sentences in each category

# %%
biographies_df.groupby('Category')['num_sentences'].sum()
# Out:
# Category
# Astronauts    477
# Chefs         423
# Name: num_sentences, dtype: int64

# %% [markdown]
# - Min/max/avg number of sentences per each category

# %%
min_sentences = biographies_df.groupby('Category')['num_sentences'].min()
avg_sentences = biographies_df.groupby('Category')['num_sentences'].mean()
max_sentences = biographies_df.groupby('Category')['num_sentences'].max()

print("Minimum Number of Sentences per Category:\n", min_sentences)
print("\nAverage Number of Sentences per Category:\n", avg_sentences)
print("\nMaximum Number of Sentences per Category:\n", max_sentences)
# Out:
# Minimum Number of Sentences per Category:
#  Category
# Astronauts    1
# Chefs         1
# Name: num_sentences, dtype: int64
#
# Average Number of Sentences per Category:
#  Category
# Astronauts    4.77
# Chefs         4.23
# Name: num_sentences, dtype: float64
#
# Maximum Number of Sentences per Category:
#  Category
# Astronauts    26
# Chefs         49
# Name: num_sentences, dtype: int64

# %% [markdown]
# - Box plots for both categories

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=biographies_df, x='Category', y='num_sentences')
plt.title('Box Plot of Number of Sentences per Category')
plt.xlabel('Category')
plt.ylabel('Number of Sentences')
plt.show()

# %% [markdown]
# - Box Plot of Number of Sentences for 'Astronauts'
# - Box Plot of Number of Sentences for 'Chefs'

# %%
categories = biographies_df['Category'].unique()

for category in categories:
    plt.figure(figsize=(8, 4)) 
    
    data = biographies_df[biographies_df['Category'] == category]['num_sentences']

    plt.boxplot(data)

    plt.title(f'Box Plot of Number of Sentences for Category: {category}')
    plt.ylabel('Number of Sentences')

    plt.show()

# %% [markdown]
# - Histogram of Number of Sentences for both categories

# %%
plt.figure(figsize=(12, 6))

#for each category
for category in biographies_df['Category'].unique():
    data = biographies_df[biographies_df['Category'] == category]['num_sentences']
    plt.hist(data, bins=20, alpha=0.5, label=category, density=True)

plt.title('Histogram of Number of Sentences per Category')
plt.xlabel('Number of Sentences')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
#  - Histogram of Number of Sentences for 'Astronauts'
#  - Histogram of Number of Sentences for 'Chefs'

# %%
categories = biographies_df['Category'].unique()
for category in categories:
    plt.figure(figsize=(8, 4))  
    data = biographies_df[biographies_df['Category'] == category]['num_sentences']
    plt.hist(data, bins=20, alpha=0.5)
    plt.title(f'Histogram of Number of Sentences for Category: {category}')
    plt.xlabel('Number of Sentences')
    plt.ylabel('Frequency')
    plt.show()

# %%
def collect_bigrams(tokens):
    bigrams = nltk.bigrams(tokens)
    occurences = {}
    for bigram in bigrams:
        if occurences.get(bigram):
            occurences[bigram] += 1
        else:
            occurences[bigram] = 1
    return occurences

# %%
bigrams1 = collect_bigrams(tokens1)
bigrams2 = collect_bigrams(tokens2)

# %%
bi_gram_counts = biographies_df['bi_grams'].apply(Counter)

# %% [markdown]
# - bi_gram counts for each category

# %%
bi_gram_counts
# Out:
# 0      {('cai', 'xuzhe'): 1, ('xuzhe', 'chinese'): 1,...
# 1      {('carl', 'erwin'): 1, ('erwin', 'walz'): 1, (...
# 2      {('carl', 'joseph'): 1, ('joseph', 'meade'): 1...
# 3      {('carlos', 'ismael'): 1, ('ismael', 'noriega'...
# 4      {('pyotr', 'valerievich'): 1, ('valerievich', ...
#                              ...
# 195    {('julien', 'royer'): 1, ('royer', 'bear'): 2,...
# 196    {('juliet', 'corson'): 1, ('corson', 'january'...
# 197    {('beverly', 'kim'): 1, ('kim', 'james'): 1, (...
# 198    {('patrick', 'chef'): 1, ('chef', 'proprietor'...
# 199    {('paul', 'ainsworth'): 2, ('ainsworth', 'bear...
# Name: bi_grams, Length: 200, dtype: object

# %%
total_bi_gram_counts = biographies_df.groupby('Category')['bi_gram_counts'].apply(lambda x: sum(x, Counter()))
print("Total number of bi-gram occurrences per category:")
print(total_bi_gram_counts)
# Out:
# Total number of bi-gram occurrences per category:
# Category
# Astronauts  (cai, xuzhe)         1.0
#             (xuzhe, chinese)     1.0
#             (chinese, 蔡旭哲)       1.0
#             (蔡旭哲, bear)          1.0
#             (bear, chinese)      1.0
#                                 ...
# Chefs       (work, gary)         1.0
#             (gary, rhode)        1.0
#             (rhode, gordon)      1.0
#             (ramsay, marcus)     1.0
#             (marcus, wareing)    1.0
# Name: bi_gram_counts, Length: 15320, dtype: float64

# %% [markdown]
# - min/max/avg number of bi-gram occurrences per sentence per category.

# %%
min_per_category = biographies_df.groupby('Category')['bi_grams'].apply(lambda x: np.min([len(bi_gram) for bi_gram in x]))
max_per_category = biographies_df.groupby('Category')['bi_grams'].apply(lambda x: np.max([len(bi_gram) for bi_gram in x]))
avg_per_category = biographies_df.groupby('Category')['bi_grams'].apply(lambda x: np.mean([len(bi_gram) for bi_gram in x]))

print("\nMin number of bi-gram occurrences per sentence per category:")
print(min_per_category)

print("\nMax number of bi-gram occurrences per sentence per category:")
print(max_per_category)

print("\nAverage number of bi-gram occurrences per sentence per category:")
print(avg_per_category)
# Out:
# Min number of bi-gram occurrences per sentence per category:
# Category
# Astronauts    6
# Chefs         3
# Name: bi_grams, dtype: int64
#
# Max number of bi-gram occurrences per sentence per category:
# Category
# Astronauts    311
# Chefs         526
# Name: bi_grams, dtype: int64
#
# Average number of bi-gram occurrences per sentence per category:
# Category
# Astronauts    48.78
# Chefs         43.32
# Name: bi_grams, dtype: float64
