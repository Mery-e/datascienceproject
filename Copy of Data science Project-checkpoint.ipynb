# %% [markdown]
# # Part 1: Data Collection for Text Comparison and Clustering
#
# ## Data Collection

# %%
# !pip install wikipedia
# !pip install SPARQLWrapper
# !pip install nltk
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !pip install wordcloud
# !pip install seaborn
# !pip install collections
# !pip install numpy
# !pip install matplotlib
# !pip install wordcloud
# !pip install spacy
# !pip install seaborn
# !pip install collections
# !pip install numpy
# !pip install matplotlib
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2024.6.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia) (2.5)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11680 sha256=6e2c7b3d178e5544ce9d034dac5751f9f8a0e66261673acba755ffe264adf0e2
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1 (from SPARQLWrapper)
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 10.7 MB/s eta 0:00:00
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=6.1.1->SPARQLWrapper)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Installing collected packages: isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 isodate-0.6.1 rdflib-7.0.0
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 74.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import wikipedia
import requests
from bs4 import BeautifulSoup
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
from urllib.parse import quote
from typing import List, Dict, Tuple
import requests
import json
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import spacy
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from collections import Counter
import numpy as np

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
categories = [("Astronauts", "dbo:Astronaut"), ("Chefs", "dbo:Chef")]
max_biographies_per_category = 100
max_biographies = 100

# %% [markdown]
# **1.1 Extracting Biographies**

# %%
def get_bibliography(category: str, rdf_type: str, max_biographies: int ) -> List[str]:
    """
    Retrieve biographies from Wikipedia for a specified category and RDF type.

    Args:
        category (str): The category name (e.g., "Astronauts", "Chefs").
        rdf_type (str): The RDF type of the category (e.g., "dbo:Astronaut", "dbo:Chef").
        max_biographies (int): Maximum number of biographies to collect (default: 100).

    Returns:
        List[str]: A list of biographies extracted from Wikipedia.
    """
    biographies = []

    encoded_category = quote(category)  # Encode the category name for use in the SPARQL query

    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    query = f"""
        PREFIX dbo: <http://dbpedia.org/ontology/>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

        SELECT DISTINCT ?page ?summary
        WHERE {{
            # ?page rdf:type {rdf_type} .
            # ?page rdfs:label ?label .
            # ?page dbo:abstract ?summary .
            FILTER (LANG(?label) = 'en') .
            FILTER (LANG(?summary) = 'en') .
        }}
        LIMIT {max_biographies}
    """

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    results = sparql.query().convert()

    for result in results["results"]["bindings"]:
        biography = result["summary"]["value"]
        biographies.append(biography)

    return biographies

# %% [markdown]
# **1.2 Extracting Knowledge Graph Facts**

# %%
def extract_kg_facts(person_names: List[str]) -> Dict[str, List[Dict]]:
    """
    Extract KG Graph facts (RDF triples) for the specified people from DBpedia.

    Args:
        person_names (List[str]): List of person names.

    Returns:
        Dict[str, List[Dict]]: A dictionary containing KG Graph facts for each person.
    """
    kg_facts = {}

    for person_name in person_names:
        kg_facts[person_name] = []

        sparql = SPARQLWrapper("http://dbpedia.org/sparql")
        encoded_person_name = quote(person_name)
        query = f"""
            PREFIX dbo: <http://dbpedia.org/ontology/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            SELECT DISTINCT ?predicate ?object
            WHERE {{
                <http://dbpedia.org/resource/{encoded_person_name}> ?predicate ?object.
                FILTER (strstarts(str(?predicate), str(dbo:)))
            }}
        """

        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)

        results = sparql.query().convert()

        for result in results["results"]["bindings"]:
            predicate = result["predicate"]["value"]
            obj = result["object"]["value"]
            kg_facts[person_name].append({"predicate": predicate, "object": obj})

    return kg_facts

# %%
def get_bibliography_and_kg_facts(categories: List[Tuple[str, str]], max_biographies: int = 100) -> Dict[str, Dict[str, List[Dict]]]:
    """
    Retrieve biographies from Wikipedia for specified categories and their RDF types,
    and extract KG Graph facts (RDF triples) for each person mentioned in the biographies.

    Args:
        categories (List[Tuple[str, str]]): List of tuples containing category name and RDF type.
        max_biographies (int): Maximum number of biographies to collect for each category (default: 100).

    Returns:
        Dict[str, Dict[str, List[Dict]]]: A dictionary containing biographies and KG Graph facts for each category.
    """
    data = {}

    for category, rdf_type in categories:
        biographies = get_bibliography(category, rdf_type, max_biographies=max_biographies)
        person_names = [biography.split()[0] for biography in biographies]  # Extract person names from biographies
        kg_facts = extract_kg_facts(person_names)
        data[category] = {"biographies": biographies, "kg_facts": kg_facts}

    return data

# %%
data = {}

for category, rdf_type in categories:
    biographies_and_facts = get_bibliography_and_kg_facts([(category, rdf_type)], max_biographies=max_biographies_per_category)
    data[category] = biographies_and_facts[category]

for category, category_data in data.items():
    print(f"Category: {category}")
    print("Biographies:")
    for idx, biography in enumerate(category_data["biographies"][:5]):
        print(f"{idx + 1}. {biography}")
    print("KG Facts:")
    for person, facts in category_data["kg_facts"].items():
        print(f"KG Facts for {person}:")
        for fact in facts:
            print(f"- {fact['predicate']}: {fact['object']}")
# Out:
# Streaming output truncated to the last 5000 lines.
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Jeb_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Archie_Bradley_(baseball)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Charles_Bradley_(singer)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Karen_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Keegan_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Kepler_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Jean-Claude_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Disappearance_of_Amy_Lynn_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Arthur_Granville_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Marion_Zimmer_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Mick_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Omar_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Shaun_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Shawn_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Bob_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/George_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Henry_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/James_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Joe_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/John_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Loretta_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Luther_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Martin_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Milton_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Robert_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Stephen_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Tom_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/W._C._Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/William_Bradley_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Yasemin_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Gwendolyn_Bradley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Evalie_A._Bradley
# - http://dbpedia.org/ontology/abstract: Bradley ist ein männlicher Vorname, der insbesondere im englischsprachigen Raum verbreitet ist.
# - http://dbpedia.org/ontology/abstract: Bradley è un nome proprio di persona inglese maschile.
# - http://dbpedia.org/ontology/abstract: Бре́длі (англ. Bradley) — англійське чоловіче особове ім'я.
# - http://dbpedia.org/ontology/wikiPageLength: 9327
# - http://dbpedia.org/ontology/meaning: "broad wood", "broad clearing"
# KG Facts for Brian:
# - http://dbpedia.org/ontology/wikiPageID: 3173243
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1118949884
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/2007_World_Figure_Skating_Championships
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Breton_language
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bretons
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian's_Song
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Ah_Yat
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Alderson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Aldiss
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Asamoah
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Austin_Green
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Bannister
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Bass
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Blessed
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Boitano
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Bollinger
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Bonsall
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Boru
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Broomell
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Clough
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Cole_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Cook_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Cornell
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Cowen
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Dabul
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_De_Palma
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Dennehy
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Dixon_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Dowling_(presenter)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Eno
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Epstein
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Flynn_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Folkerts
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Francis_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Gaine
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Ginsberg
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Gottfried
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Gowins
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Grazer
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Green_(Torchwood)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Gutekunst
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Haley
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Horwitz
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Hutton,_Baron_Hutton
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Joo
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Joubert
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Lara
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Laudrup
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Lewerke
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Littrell
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_May
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_McConaghy
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_McKnight
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Molko
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Moorman
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Mulroney
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_O'Conner
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_O'Driscoll
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_O'Keefe
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_O'Keefe_(baseball)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_O'Keeffe
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Orser
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Peaker
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Peets
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Piccolo
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Randle
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Ransom_(gridiron_football)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Retterer
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Ross_(journalist)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Savoy
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Schneider
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Serven
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Sims
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Snitker
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Stelter
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Stephney
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Sweeney
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Sweeney_(sailor)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Teacher
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Tyler
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Urlacher
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Viloria
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Westbrook
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Williams
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_de_la_Puente
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brianna_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Death_of_Brian_Deneke
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_Walker
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Video_Game_High_School
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Donald_Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/East_Anglia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/English-speaking_world
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Gale_Harold
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Graham_Chapman
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Monty_Python's_Life_of_Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Morgan_Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/NBC_Nightly_News
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/The_Magic_Roundabout
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bryant_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bryon
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Limmy
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Denis_Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brittany
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Burying_Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Category:Irish-language_masculine_given_names
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Celtic_languages
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Category:Surnames_of_Irish_origin
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/What_About_Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Given_name
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Havergal_Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Irish_diaspora
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Family_Guy
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brayan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Breanna_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_(mythology)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Griffin
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Kinney
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Tucker_(screenwriter)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Wilson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brianne_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brina_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Nickname
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Ninja_Sex_Party
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Norman_Conquest
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Normans
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/List_of_Irish-language_given_names
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Irish_language
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Taoiseach
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/The_Breakfast_Club
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Category:English-language_masculine_given_names
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Category:English_masculine_given_names
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Category:French-language_surnames
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Kidnapping_of_Elizabeth_Smart
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Killing_of_Gabby_Petito
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Surname
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/High_King_of_Ireland
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Marilyn_Manson
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Mary_Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bryan_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Bryan_(surname)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/O'Brian
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Occitan_language
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Seth_MacFarlane
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_(dog)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Allen_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Andersen_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Anderson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Becker_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Bell_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Bennett_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Blake_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Bowman_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Briggs_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Brown_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Burns_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Byrne_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Campbell_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Carroll_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Clark_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Clarke_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Coleman_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Collins_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Cox_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Cummings_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Cunningham_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Davis_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Doyle_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Edwards_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Fallon_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Fitzpatrick_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Fletcher_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Freeman_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Gibson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Grant_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Green_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Hall_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Harvey_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Henderson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Higgins_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Hill_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_James_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Johnson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Johnston_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Jones_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Keith_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Kelly_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Kennedy_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Kim_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Lee_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Lewis_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_MacMahon_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Magee_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Marshall_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Martin_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Mason_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_McBride_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_McFadden_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_McLean_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Miller_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Moore_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Moran_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Mullins_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Murphy_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_O'Halloran_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_O'Neill_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_O'Sullivan_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Plummer_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Reynolds_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Roberts_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Robertson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Savage_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Schmidt_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Scott_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Shaw_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Simmons_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Smith_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Smyth_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Stack_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Stafford_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Stewart_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Sullivan_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Thompson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Thomson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Tucker_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Turner_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Tyler_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Walsh_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_White_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Williams_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Wong_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Wood_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Wright_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Briant_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brien
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brion_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Jossie
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brian_Paddick
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Maggot
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Male
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Middle_Ages
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Old_Occitan
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Breanne_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Brân
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/The_Fast_and_the_Furious_(series)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Queer_as_Folk_(North_American_TV_series)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/O'Brien_(surname)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Wikipedia:Disambiguation
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian's_Song
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Ah_Yat
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Alderson
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Aldiss
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Asamoah
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Austin_Green
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Bannister
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Bass
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Blessed
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Boitano
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Bollinger
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Bonsall
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Boru
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Broomell
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Clough
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Cole_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Cook_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Cornell
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Cowen
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Dabul
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_De_Palma
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Dennehy
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Dixon_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Dowling_(presenter)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Eno
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Epstein
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Flynn_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Folkerts
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Francis_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Gaine
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Ginsberg
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Gottfried
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Gowins
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Grazer
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Green_(Torchwood)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Gutekunst
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Haley
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Horwitz
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Hutton,_Baron_Hutton
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Joo
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Joubert
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Lara
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Laudrup
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Lewerke
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Littrell
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_May
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_McConaghy
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_McKnight
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Molko
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Moorman
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Mulroney
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_O'Conner
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_O'Driscoll
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_O'Keefe
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_O'Keefe_(baseball)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_O'Keeffe
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Orser
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Peaker
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Peets
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Piccolo
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Randle
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Ransom_(gridiron_football)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Retterer
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Ross_(journalist)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Savoy
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Schneider
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Serven
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Sims
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Snitker
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Stelter
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Stephney
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Sweeney
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Sweeney_(sailor)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Teacher
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Tyler
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Urlacher
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Viloria
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Westbrook
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Williams
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_de_la_Puente
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brianna_(given_name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Death_of_Brian_Deneke
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Donald_Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Monty_Python's_Life_of_Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Morgan_Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Denis_Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brittany
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Burying_Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/What_About_Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Havergal_Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_(mythology)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Griffin
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Kinney
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Tucker_(screenwriter)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Wilson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brianne_(given_name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Mary_Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/O'Brian
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_(dog)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Allen_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Andersen_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Anderson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Becker_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Bell_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Bennett_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Blake_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Bowman_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Briggs_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Brown_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Burns_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Byrne_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Campbell_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Carroll_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Clark_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Clarke_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Coleman_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Collins_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Cox_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Cummings_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Cunningham_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Davis_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Doyle_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Edwards_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Fallon_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Fitzpatrick_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Fletcher_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Freeman_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Gibson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Grant_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Green_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Hall_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Harvey_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Henderson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Higgins_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Hill_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_James_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Johnson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Johnston_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Jones_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Keith_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Kelly_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Kennedy_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Kim_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Lee_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Lewis_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_MacMahon_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Magee_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Marshall_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Martin_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Mason_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_McBride_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_McFadden_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_McLean_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Miller_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Moore_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Moran_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Mullins_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Murphy_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_O'Halloran_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_O'Neill_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_O'Sullivan_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Plummer_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Reynolds_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Roberts_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Robertson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Savage_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Schmidt_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Scott_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Shaw_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Simmons_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Smith_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Smyth_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Stack_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Stafford_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Stewart_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Sullivan_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Thompson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Thomson_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Tucker_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Turner_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Tyler_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Walsh_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_White_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Williams_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Wong_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Wood_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Wright_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Briant_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Jossie
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Brian_Paddick
# ...
# - http://dbpedia.org/ontology/wikiPageLength: 2508
# KG Facts for Patrick:
# - http://dbpedia.org/ontology/wikiPageID: 12838538
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1118498372
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patric_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick,_Queensland
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick,_South_Carolina
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(1978_film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(2013_film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(2018_film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(2019_film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_1983)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_1985)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_1992)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_1994)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_2000)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_May_1998)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(footballer,_born_November_1998)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(parish)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(sportswear_company)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Don_Harris_(wrestler)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Croagh_Patrick
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Saint_Patrick
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Partick_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick,_1st_Earl_of_Salisbury
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_(surname)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_Corporation
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_County,_Virginia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Patrick_Division
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Gilla_Pátraic
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/John_Byrne_(Scottish_playwright)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick,_Queensland
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick,_South_Carolina
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(1978_film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(2013_film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(2018_film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(2019_film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_1983)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_1985)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_1992)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_1994)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_2000)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_May_1998)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(footballer,_born_November_1998)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(given_name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(parish)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(sportswear_company)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Croagh_Patrick
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Saint_Patrick
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick,_1st_Earl_of_Salisbury
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_(surname)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_Corporation
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_County,_Virginia
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Patrick_Division
# - http://dbpedia.org/ontology/wikiPageInterLanguageLink: http://ja.dbpedia.org/resource/パトリック
# - http://dbpedia.org/ontology/wikiPageLength: 1955
# KG Facts for Paul:
# - http://dbpedia.org/ontology/wikiPageID: 24092
# - http://dbpedia.org/ontology/wikiPageRevisionID: 1121143173
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Little_Witch_Academia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Alabama
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Cape_Verde
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Cornwall
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Idaho
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(American_Horror_Story)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Nestorian_patriarch)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(PJ_Morton_album)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Pokémon)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Ponomaryov)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(bakery)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(film)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(given_name)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_I_of_Russia
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_McCartney
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_Stookey
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_of_Greece
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_the_Apostle
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_the_Deacon
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paulus_Catena
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Portable_Aqua_Unit_for_Lifesaving
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Păuleasca_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Păuleni_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Păulești_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_the_Octopus
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Lucius_Aemilius_Paullus_Macedonicus
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Sir_Walter_Scott
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_Nebraska
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul,_son_of_Peter
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Life_with_Derek)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(Meletiev)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(bishop_of_Mérida)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(civil_parish)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(exarch)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(father_of_Maurice)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(nursery)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(play)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(singer)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(song)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_(surname)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_Clarke_(character)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_II_(octopus)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paul_of_Aegina
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paula_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Paulus_Alexandrinus
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Pope_Paul_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Saint_Paul_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/The_Paul
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Julius_Paulus_Prudentissimus
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Aichi_E16A
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/DNA_Productions
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/The_Beatles
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Hurricane_Paul_(1982)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Hurricane_Paul_(2006)
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/Poker_Face_Paul
# - http://dbpedia.org/ontology/wikiPageWikiLink: http://dbpedia.org/resource/St._Paul_(oratorio)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Alabama
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Cape_Verde
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Cornwall
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Idaho
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(American_Horror_Story)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Nestorian_patriarch)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(PJ_Morton_album)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Pokémon)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Ponomaryov)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(bakery)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(film)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(given_name)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_I_of_Russia
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_McCartney
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_Stookey
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_of_Greece
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_the_Apostle
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_the_Deacon
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paulus_Catena
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Portable_Aqua_Unit_for_Lifesaving
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_the_Octopus
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Lucius_Aemilius_Paullus_Macedonicus
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_Nebraska
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul,_son_of_Peter
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Life_with_Derek)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(Meletiev)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(bishop_of_Mérida)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(civil_parish)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(exarch)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(father_of_Maurice)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(nursery)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(play)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(singer)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(song)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_(surname)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_Clarke_(character)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_II_(octopus)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paul_of_Aegina
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paula_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Paulus_Alexandrinus
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Pope_Paul_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Saint_Paul_(disambiguation)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/The_Paul
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Julius_Paulus_Prudentissimus
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Hurricane_Paul_(1982)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Hurricane_Paul_(2006)
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/Poker_Face_Paul
# - http://dbpedia.org/ontology/wikiPageDisambiguates: http://dbpedia.org/resource/St._Paul_(oratorio)
# - http://dbpedia.org/ontology/wikiPageLength: 4363

# %% [markdown]
#    **1.3 Storing Data**
#    - Biographies will be stored in a Pandas DataFrame, where each row represents a biography and its associated category.
#    - Each biography will also be saved in a separate text file named **`person_category.txt`**.

# %%
def store_biographies_as_dataframe(categories: List[Tuple[str, str]], max_biographies: int) -> pd.DataFrame:
    """
    Store each biography along with its category in a Pandas DataFrame.

    Args:
        categories (List[Tuple[str, str]]): List of tuples containing category names and RDF types.
        max_biographies (int): Maximum number of biographies to collect.

    Returns:
        pd.DataFrame: DataFrame containing biographies and categories.
    """
    biographies_list = []
    categories_list = []

    for category, rdf_type in categories:
        biographies = get_bibliography(category, rdf_type, max_biographies)
        biographies_list.extend(biographies)
        categories_list.extend([category] * len(biographies))

    # Create DataFrame
    df = pd.DataFrame({"Biography": biographies_list, "Category": categories_list})
    return df

# %%
df = store_biographies_as_dataframe(categories, max_biographies)
df
# Out:
#                                              Biography    Category
# 0    Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a C...  Astronauts
# 1    Carl Erwin Walz (Colonel, USAF, Ret.) (born 6 ...  Astronauts
# 2    Carl Joseph Meade (born November 16, 1950) is ...  Astronauts
# 3    Carlos Ismael Noriega (born 8 October 1959) is...  Astronauts
# 4    Pyotr Valerievich Dubrov (Russian: Пётр Валерь...  Astronauts
# ..                                                 ...         ...
# 195  Julien Royer (born 1 September 1982) is a Fren...       Chefs
# 196  Juliet Corson (January 14, 1841 – June 18, 189...       Chefs
# 197  Beverly Kim is a James Beard Award-winning che...       Chefs
# 198  Patrick O’Connell is the chef and proprietor o...       Chefs
# 199  Paul Ainsworth (born 1979) is a British chef f...       Chefs
#
# [200 rows x 2 columns]

# %%
def store_biographies_as_text_files(categories: List[Tuple[str, str]], max_biographies: int):
    """
    Store each biography in a separate text file named person_category.txt.

    Args:
        categories (List[Tuple[str, str]]): List of tuples containing category names and RDF types.
        max_biographies (int): Maximum number of biographies to collect.
    """
    for category, rdf_type in categories:
        biographies = get_bibliography(category, rdf_type, max_biographies)
        for biography in biographies:
            # Store biography in a text file named person_category.txt
            file_name = f"{biography[:20]}_{category.replace(' ', '_')}.txt"
            with open(file_name, "w") as file:
                file.write(biography)
            print(f"File '{file_name}' created successfully.")

# %%
store_biographies_as_text_files(categories, max_biographies)
# Out:
# File 'Cai Xuzhe (Chinese: _Astronauts.txt' created successfully.
# File 'Carl Erwin Walz (Col_Astronauts.txt' created successfully.
# File 'Carl Joseph Meade (b_Astronauts.txt' created successfully.
# File 'Carlos Ismael Norieg_Astronauts.txt' created successfully.
# File 'Pyotr Valerievich Du_Astronauts.txt' created successfully.
# File 'Pyotr Ilyich Klimuk _Astronauts.txt' created successfully.
# File 'Pyotr Ivanovich Kolo_Astronauts.txt' created successfully.
# File 'Robert Michael "Bob"_Astronauts.txt' created successfully.
# File 'Robert Lee "Bobby" S_Astronauts.txt' created successfully.
# File 'Robert Brent "Bob" T_Astronauts.txt' created successfully.
# File 'Roberta Lynn Bondar _Astronauts.txt' created successfully.
# File 'Brigadier Roberto Vi_Astronauts.txt' created successfully.
# File 'Rodolfo Neri Vela (b_Astronauts.txt' created successfully.
# File 'Roger Bruce Chaffee _Astronauts.txt' created successfully.
# File 'Roger Keith Crouch (_Astronauts.txt' created successfully.
# File 'Roger E. Kanet (born_Astronauts.txt' created successfully.
# File 'Roman Yurievich Roma_Astronauts.txt' created successfully.
# File 'Ronald Ellwin Evans _Astronauts.txt' created successfully.
# File 'Ronald John Garan Jr_Astronauts.txt' created successfully.
# File 'Ronald John Grabe (b_Astronauts.txt' created successfully.
# File 'Ronald "Ron" Michael_Astronauts.txt' created successfully.
# File 'Ronald Erwin McNair _Astronauts.txt' created successfully.
# File 'Ronald Anthony Paris_Astronauts.txt' created successfully.
# File 'Samantha Cristoforet_Astronauts.txt' created successfully.
# File 'Samuel Thornton Durr_Astronauts.txt' created successfully.
# File 'Sandra Hall Magnus (_Astronauts.txt' created successfully.
# File 'Sarah Gillis is an A_Astronauts.txt' created successfully.
# File 'Satoshi Furukawa (古川_Astronauts.txt' created successfully.
# File 'Scott Douglas "Scoot_Astronauts.txt' created successfully.
# File 'Malcolm Scott Carpen_Astronauts.txt' created successfully.
# File 'Scott David Tingle (_Astronauts.txt' created successfully.
# File 'Scott Edward Parazyn_Astronauts.txt' created successfully.
# File 'Scott Jay "Doc" Horo_Astronauts.txt' created successfully.
# File 'Scott Joseph Kelly (_Astronauts.txt' created successfully.
# File 'Barry Eugene "Butch"_Astronauts.txt' created successfully.
# File 'Bernard Anthony Harr_Astronauts.txt' created successfully.
# File 'Bertram Raoul Bulkin_Astronauts.txt' created successfully.
# File 'Bertalan Farkas (bor_Astronauts.txt' created successfully.
# File 'William Barton Bridg_Astronauts.txt' created successfully.
# File 'Bjarni Valdimar Tryg_Astronauts.txt' created successfully.
# File 'Robert Louis Behnken_Astronauts.txt' created successfully.
# File 'Bonnie Jeanne Dunbar_Astronauts.txt' created successfully.
# File 'Boris Dmitriyevich A_Astronauts.txt' created successfully.
# File 'Boris Vladimirovich _Astronauts.txt' created successfully.
# File 'Boris Valentinovich _Astronauts.txt' created successfully.
# File 'Boris Borisovich Yeg_Astronauts.txt' created successfully.
# File 'Brent Ward Jett Jr. _Astronauts.txt' created successfully.
# File 'Brewster Hopkinson S_Astronauts.txt' created successfully.
# File 'William Brian Binnie_Astronauts.txt' created successfully.
# File 'Brian Duffy (born Ju_Astronauts.txt' created successfully.
# File 'Brian Todd O'Leary (_Astronauts.txt' created successfully.
# File 'David Carl Hilmers, _Astronauts.txt' created successfully.
# File 'David Cornell Leestm_Astronauts.txt' created successfully.
# File 'David McDowell Brown_Astronauts.txt' created successfully.
# File 'David Mathieson "Dav_Astronauts.txt' created successfully.
# File 'David Saint-Jacques _Astronauts.txt' created successfully.
# File 'David Randolph Scott_Astronauts.txt' created successfully.
# File 'David Alexander Wolf_Astronauts.txt' created successfully.
# File 'Donald Kent "Deke" S_Astronauts.txt' created successfully.
# File 'Deng Qingming (simpl_Astronauts.txt' created successfully.
# File 'Denis Vladimirovich _Astronauts.txt' created successfully.
# File 'Deniz Melissa Burnha_Astronauts.txt' created successfully.
# File 'Dennis Anthony Tito _Astronauts.txt' created successfully.
# File 'Anna Menon is an Ame_Astronauts.txt' created successfully.
# File 'John Oliver Creighto_Astronauts.txt' created successfully.
# File 'John Sumter Bull (Se_Astronauts.txt' created successfully.
# File 'John Watts Young (Se_Astronauts.txt' created successfully.
# File 'Jon Andrew McBride (_Astronauts.txt' created successfully.
# File 'Joseph Albert Walker_Astronauts.txt' created successfully.
# File 'Joseph Michael "Joe"_Astronauts.txt' created successfully.
# File 'Joseph Percival "Joe_Astronauts.txt' created successfully.
# File 'Joseph Peter Kerwin _Astronauts.txt' created successfully.
# File 'Joseph Richard Tanne_Astronauts.txt' created successfully.
# File 'Josh Aaron Cassada (_Astronauts.txt' created successfully.
# File 'Joshua Kutryk (born _Astronauts.txt' created successfully.
# File 'José Moreno Hernánde_Astronauts.txt' created successfully.
# File 'Judith Arlene Resnik_Astronauts.txt' created successfully.
# File 'Patricia Consolatrix_Astronauts.txt' created successfully.
# File 'Patrick Pierre Roger_Astronauts.txt' created successfully.
# File 'Patrick Graham Forre_Astronauts.txt' created successfully.
# File 'Paul Joseph Weitz (J_Astronauts.txt' created successfully.
# File 'Paul Scott "Paco" Lo_Astronauts.txt' created successfully.
# File 'Paul Desmond Scully-_Astronauts.txt' created successfully.
# File 'Paul William Richard_Astronauts.txt' created successfully.
# File 'Pavel Ivanovich Bely_Astronauts.txt' created successfully.
# File 'Pavel Romanovich Pop_Astronauts.txt' created successfully.
# File 'Pavel Vladimirovich _Astronauts.txt' created successfully.
# File 'Pedro Francisco Duqu_Astronauts.txt' created successfully.
# File 'Peggy Annette Whitso_Astronauts.txt' created successfully.
# File 'Charles "Pete" Conra_Astronauts.txt' created successfully.
# File 'Peter Siebold (born _Astronauts.txt' created successfully.
# File 'Peter Jeffrey Kelsay_Astronauts.txt' created successfully.
# File 'Prof. Dr. Reinhard A_Astronauts.txt' created successfully.
# File 'Reinhold Ewald (born_Astronauts.txt' created successfully.
# File 'Renate Luise Brümmer_Astronauts.txt' created successfully.
# File 'Rex Joseph Walheim (_Astronauts.txt' created successfully.
# File 'Margaret Rhea Seddon_Astronauts.txt' created successfully.
# File 'Richard Alan Searfos_Astronauts.txt' created successfully.
# File 'Richard Earl "Dick" _Astronauts.txt' created successfully.
# File 'Richard Francis Gord_Astronauts.txt' created successfully.
# File 'Carla Hall (born May_Chefs.txt' created successfully.
# File 'Carme Ruscalleda i S_Chefs.txt' created successfully.
# File 'Carrie Nahabedian (b_Chefs.txt' created successfully.
# File 'Carson Gulley (June _Chefs.txt' created successfully.
# File 'Catherine Ann Cora i_Chefs.txt' created successfully.
# File 'Beau MacMillan is an_Chefs.txt' created successfully.
# File 'Priscilla Martel is _Chefs.txt' created successfully.
# File 'Roberto Donna is an _Chefs.txt' created successfully.
# File 'Rochelle Adonis is a_Chefs.txt' created successfully.
# File 'Rahman "Rock" Harper_Chefs.txt' created successfully.
# File 'Roger Vergé (French _Chefs.txt' created successfully.
# File 'Rokusaburo Michiba (_Chefs.txt' created successfully.
# File 'Roland Mesnier (July_Chefs.txt' created successfully.
# File 'French-born chef Rol_Chefs.txt' created successfully.
# File 'Ron Siegel (born 196_Chefs.txt' created successfully.
# File 'Rosemary Jacqueline _Chefs.txt' created successfully.
# File 'Roy Choi (born Febru_Chefs.txt' created successfully.
# File 'Roy Fares (born 16 S_Chefs.txt' created successfully.
# File 'Roy Yamaguchi (born _Chefs.txt' created successfully.
# File 'Kim Hee-Tae (Korean:_Chefs.txt' created successfully.
# File 'Sami Tamimi is a Pal_Chefs.txt' created successfully.
# File 'Samin Nosrat (Persia_Chefs.txt' created successfully.
# File 'Sanjeev Kapoor (born_Chefs.txt' created successfully.
# File 'Sanjyot Keer (born J_Chefs.txt' created successfully.
# File 'Santiago Santamaria _Chefs.txt' created successfully.
# File 'Sara Moulton (born F_Chefs.txt' created successfully.
# File 'Sarah Grueneberg is _Chefs.txt' created successfully.
# File 'Saransh Goila (born _Chefs.txt' created successfully.
# File 'Sarma Melngailis (bo_Chefs.txt' created successfully.
# File 'Satwant Singh "Sat" _Chefs.txt' created successfully.
# File 'Scott Conant (born F_Chefs.txt' created successfully.
# File 'Scott Leibfried (bor_Chefs.txt' created successfully.
# File 'Scott Peacock (born _Chefs.txt' created successfully.
# File 'Elia Aboumrad (born _Chefs.txt' created successfully.
# File 'Enrique Olvera (born_Chefs.txt' created successfully.
# File 'Morgan Murphy is a n_Chefs.txt' created successfully.
# File 'M.S. Krishna Iyer (b_Chefs.txt' created successfully.
# File 'Nawab Mehboob Alam K_Chefs.txt' created successfully.
# File 'Melissa Donovan d'Ar_Chefs.txt' created successfully.
# File 'Omar Allibhoy is a S_Chefs.txt' created successfully.
# File 'Priya Krishna is an _Chefs.txt' created successfully.
# File 'Sarah Kramer is a Ca_Chefs.txt' created successfully.
# File 'Belinda Leong is an _Chefs.txt' created successfully.
# File 'Benjamin O'Donoghue _Chefs.txt' created successfully.
# File 'Ben Pollinger is the_Chefs.txt' created successfully.
# File 'Ben Shewry (born 197_Chefs.txt' created successfully.
# File 'Benedetto D'Epiro (b_Chefs.txt' created successfully.
# File 'Benoît Violier (Fren_Chefs.txt' created successfully.
# File 'Bent Stiansen (born _Chefs.txt' created successfully.
# File 'Bernard Daniel Jacqu_Chefs.txt' created successfully.
# File 'Elizabeth "Betty" R._Chefs.txt' created successfully.
# File 'Biba Caggiano (Octob_Chefs.txt' created successfully.
# File 'Thomas Hylton "Bill"_Chefs.txt' created successfully.
# File 'William Granger is a_Chefs.txt' created successfully.
# File 'Bill Harmsen (June 2_Chefs.txt' created successfully.
# File 'Björn Frantzén (born_Chefs.txt' created successfully.
# File 'Bob Blumer was the c_Chefs.txt' created successfully.
# File 'Robert Earl Deen (bo_Chefs.txt' created successfully.
# File 'Robert William Flay _Chefs.txt' created successfully.
# File 'Pablo Logro, also kn_Chefs.txt' created successfully.
# File 'Brad Farmerie was th_Chefs.txt' created successfully.
# File 'Bradley Ogden is a T_Chefs.txt' created successfully.
# File 'Brian James Turner C_Chefs.txt' created successfully.
# File 'David Bouley (born M_Chefs.txt' created successfully.
# File 'David Carmichael is _Chefs.txt' created successfully.
# File 'David Chang (Korean:_Chefs.txt' created successfully.
# File 'David Kinch (born Ap_Chefs.txt' created successfully.
# File 'David Muñoz Rosillo _Chefs.txt' created successfully.
# File 'David Rocco (born Ju_Chefs.txt' created successfully.
# File 'David Ruggerio (born_Chefs.txt' created successfully.
# File 'William Dean Fearing_Chefs.txt' created successfully.
# File 'Delia Ann Smith CH C_Chefs.txt' created successfully.
# File 'Alfred Portale (born_Chefs.txt' created successfully.
# File 'Andrea Reusing is an_Chefs.txt' created successfully.
# File 'Ann Kim is a James B_Chefs.txt' created successfully.
# File 'Anne Byrn (Nashville_Chefs.txt' created successfully.
# File 'Anne Kearney is an A_Chefs.txt' created successfully.
# File 'Antony J. Ballard is_Chefs.txt' created successfully.
# File 'Holger Stromberg (bo_Chefs.txt' created successfully.
# File 'Homaro "Omar" Cantu _Chefs.txt' created successfully.
# File 'Hubert Keller is a n_Chefs.txt' created successfully.
# File 'Hugh Acheson (born N_Chefs.txt' created successfully.
# File 'Jon Hill (c. 1954) i_Chefs.txt' created successfully.
# File 'Jonnie Boer (born Ja_Chefs.txt' created successfully.
# File 'Jonny Lake is a Cana_Chefs.txt' created successfully.
# File 'Jordi Cruz Mas (born_Chefs.txt' created successfully.
# File 'Jordi Roca i Fontané_Chefs.txt' created successfully.
# File 'Joseph 'JJ' Johnson _Chefs.txt' created successfully.
# File 'Josh Emett is a chef_Chefs.txt' created successfully.
# File 'Joyce Chen (née Liao_Chefs.txt' created successfully.
# File 'Joyce Goldstein (bor_Chefs.txt' created successfully.
# File 'Joël Robuchon (Frenc_Chefs.txt' created successfully.
# File 'Juan Mari Arzak Arra_Chefs.txt' created successfully.
# File 'Judy Joo is a chef a_Chefs.txt' created successfully.
# File 'Julia Carolyn Child _Chefs.txt' created successfully.
# File 'Julien Royer (born 1_Chefs.txt' created successfully.
# File 'Juliet Corson (Janua_Chefs.txt' created successfully.
# File 'Beverly Kim is a Jam_Chefs.txt' created successfully.
# File 'Patrick O’Connell is_Chefs.txt' created successfully.
# File 'Paul Ainsworth (born_Chefs.txt' created successfully.

# %% [markdown]
#    - The knowledge graph facts will be stored in a JSON file, mapped back to each person.

# %%
def store_kg_facts_as_json(kg_facts: Dict[str, List[Dict]], file_path: str):
    """
    Store the knowledge graph facts in a JSON file mapped back to each person.

    Args:
        kg_facts (Dict[str, List[Dict]]): A dictionary containing KG Graph facts for each person.
        file_path (str): Path to the JSON file.
    """
      # Extract KG facts for each person
    person_names = df["Biography"].apply(lambda x: x.split('/')[-1]).tolist()
    kg_facts = extract_kg_facts(person_names)
    print("KG facts extracted successfully.")

    # Store KG facts in a JSON file
    with open("kg_facts.json", "w") as file:
        json.dump(kg_facts, file)
    print("JSON file 'kg_facts.json' created successfully.")

# %%
file_path = "kg_facts.json"
kg_facts = extract_kg_facts(person_names)
store_kg_facts_as_json(kg_facts, file_path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     925             else:
# --> 926                 response = urlopener(request)
#     927             return response, self.returnFormat
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#
# HTTPError: HTTP Error 414: Request-URI Too Large
#
# During handling of the above exception, another exception occurred:
#
# URITooLong                                Traceback (most recent call last)
# <ipython-input-19-8d7d8c060fe2> in <cell line: 2>()
#       1 file_path = "kg_facts.json"
# ----> 2 kg_facts = extract_kg_facts(person_names)
#       3 store_kg_facts_as_json(kg_facts, file_path)
#
# <ipython-input-6-e376841adffb> in extract_kg_facts(person_names)
#      29         sparql.setReturnFormat(JSON)
#      30
# ---> 31         results = sparql.query().convert()
#      32
#      33         for result in results["results"]["bindings"]:
#
# /usr/local/lib/python3.10/dist-packages/SPARQLWrapper/Wrapper.py in query(self)
#     958         :rtype: :class:`QueryResult` instance
#     959         """
# --> 960         return QueryResult(self._query())
#     961
#     962     def queryAndConvert(self) -> "QueryResult.ConvertResult":
#
# /usr/local/lib/python3.10/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     934                 raise Unauthorized(e.read())
#     935             elif e.code == 414:
# --> 936                 raise URITooLong(e.read())
#     937             elif e.code == 500:
#     938                 raise EndPointInternalError(e.read())
#
# URITooLong: URITooLong: The URI requested by the client is longer than the server is willing to interpret. Check if the request was sent using GET method instead of POST method..
#
# Response:
# b'<html>\r\n<head><title>414 Request-URI Too Large</title></head>\r\n<body>\r\n<center><h1>414 Request-URI Too Large</h1></center>\r\n<hr><center>nginx/1.18.0</center>\r\n</body>\r\n</html>\r\n'

# %%
file_path = "kg_facts.json"
store_kg_facts_as_json(kg_facts , file_path)

# %% [markdown]
# ## Data Analysis: Text Data

# %% [markdown]
# ### Preprocessing Function (`preprocess_text`):
# 1. Normalize each sentence to lowercase.
# 2. Remove stopwords .
# 3. Join the remaining tokens back into sentences.

# %%
nlp = spacy.load("en_core_web_sm")

# %%
biographies_df = df


def preprocess_text(text):
    doc = nlp(text)  # Tokenize
    sentences = [sent.text for sent in doc.sents]  # Segment into sentences
    return sentences


biographies_df['preprocessed_sentences'] = biographies_df['Biography'].apply(preprocess_text)

def preprocess_tokens(text):
    doc = nlp(text.lower())  # Tokenize and normalize to lowercase
    # Remove stopwords, punctuation, and non-alphabetic tokens
    preprocessed_text = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]
    return preprocessed_text

biographies_df['preprocessed_text'] = biographies_df['Biography'].apply(preprocess_tokens)

# %%
df.head()
# Out:
#                                            Biography    Category  \
# 0  Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a C...  Astronauts
# 1  Carl Erwin Walz (Colonel, USAF, Ret.) (born 6 ...  Astronauts
# 2  Carl Joseph Meade (born November 16, 1950) is ...  Astronauts
# 3  Carlos Ismael Noriega (born 8 October 1959) is...  Astronauts
# 4  Pyotr Valerievich Dubrov (Russian: Пётр Валерь...  Astronauts
#
#                               preprocessed_sentences  \
# 0  [Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a ...
# 1  [Carl Erwin Walz (Colonel, USAF, Ret.) (born 6...
# 2  [Carl Joseph Meade (born November 16, 1950) is...
# 3  [Carlos Ismael Noriega (born 8 October 1959) i...
# 4  [Pyotr Valerievich Dubrov (Russian: Пётр Валер...
#
#                                    preprocessed_text
# 0  [cai, xuzhe, chinese, 蔡旭哲, bear, chinese, peop...
# 1  [carl, erwin, walz, colonel, usaf, ret, bear, ...
# 2  [carl, joseph, meade, bear, november, nasa, as...
# 3  [carlos, ismael, noriega, bear, october, peruv...
# 4  [pyotr, valerievich, dubrov, russian, пётр, ва...

# %%
def get_all_tokens(df, category):
    tokens = []
    for series in df[df["Category"] == category]['preprocessed_text']:
        for t in series:
            tokens.append(t)
    return tokens

# %%
CATEGORY1 = 'Astronauts'
CATEGORY2 = 'Chefs'

# %%
tokens1 = get_all_tokens(df, CATEGORY1)
tokens2 = get_all_tokens(df, CATEGORY2)

# %% [markdown]
# - Vocabulary: 50 most frequent words and word cloud for each category.

# %%
import collections
def make_wordcloud(tokens, n_words):
    data = collections.Counter(tokens).most_common(n_words)
    word_frequencies = {word: freq for word, freq in data}

    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

    plt.figure(figsize=(8, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %% [markdown]
# - wordcloud for the category : 'Astronauts'

# %%
make_wordcloud(tokens1, 50)

# %% [markdown]
# - wordcloud for the category : 'Chefs'

# %%
make_wordcloud(tokens2, 50)

# %%
biographies_df['num_sentences'] = biographies_df['preprocessed_sentences'].apply(len)

# %%
df
# Out:
#                                              Biography    Category  \
# 0    Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a C...  Astronauts
# 1    Carl Erwin Walz (Colonel, USAF, Ret.) (born 6 ...  Astronauts
# 2    Carl Joseph Meade (born November 16, 1950) is ...  Astronauts
# 3    Carlos Ismael Noriega (born 8 October 1959) is...  Astronauts
# 4    Pyotr Valerievich Dubrov (Russian: Пётр Валерь...  Astronauts
# ..                                                 ...         ...
# 195  Julien Royer (born 1 September 1982) is a Fren...       Chefs
# 196  Juliet Corson (January 14, 1841 – June 18, 189...       Chefs
# 197  Beverly Kim is a James Beard Award-winning che...       Chefs
# 198  Patrick O’Connell is the chef and proprietor o...       Chefs
# 199  Paul Ainsworth (born 1979) is a British chef f...       Chefs
#
#                                 preprocessed_sentences  \
# 0    [Cai Xuzhe (Chinese: 蔡旭哲; born May 1976) is a ...
# 1    [Carl Erwin Walz (Colonel, USAF, Ret.) (born 6...
# 2    [Carl Joseph Meade (born November 16, 1950) is...
# 3    [Carlos Ismael Noriega (born 8 October 1959) i...
# 4    [Pyotr Valerievich Dubrov (Russian: Пётр Валер...
# ..                                                 ...
# 195  [Julien Royer (born 1 September 1982) is a Fre...
# 196  [Juliet Corson (January 14, 1841 – June 18, 18...
# 197  [Beverly Kim is a James Beard Award-winning ch...
# 198  [Patrick O’Connell is the chef and proprietor ...
# 199  [Paul Ainsworth (born 1979) is a British chef ...
#
#                                      preprocessed_text  num_sentences
# 0    [cai, xuzhe, chinese, 蔡旭哲, bear, chinese, peop...              1
# 1    [carl, erwin, walz, colonel, usaf, ret, bear, ...              3
# 2    [carl, joseph, meade, bear, november, nasa, as...              1
# 3    [carlos, ismael, noriega, bear, october, peruv...              1
# 4    [pyotr, valerievich, dubrov, russian, пётр, ва...              1
# ..                                                 ...            ...
# 195  [julien, royer, bear, september, french, chef,...              4
# 196  [juliet, corson, january, june, leader, cooker...              2
# 197  [beverly, kim, james, beard, award, win, chef,...              2
# 198  [patrick, chef, proprietor, inn, little, washi...              1
# 199  [paul, ainsworth, bear, british, chef, southam...              3
#
# [200 rows x 5 columns]

# %% [markdown]
# - sum of sentences in each category

# %%
biographies_df.groupby('Category')['num_sentences'].sum()
# Out:
# Category
# Astronauts    477
# Chefs         423
# Name: num_sentences, dtype: int64

# %% [markdown]
# - Min/max/avg number of sentences per each category

# %%
min_sentences = biographies_df.groupby('Category')['num_sentences'].min()
avg_sentences = biographies_df.groupby('Category')['num_sentences'].mean()
max_sentences = biographies_df.groupby('Category')['num_sentences'].max()

print("Minimum Number of Sentences per Category:\n", min_sentences)
print("\nAverage Number of Sentences per Category:\n", avg_sentences)
print("\nMaximum Number of Sentences per Category:\n", max_sentences)
# Out:
# Minimum Number of Sentences per Category:
#  Category
# Astronauts    1
# Chefs         1
# Name: num_sentences, dtype: int64
#
# Average Number of Sentences per Category:
#  Category
# Astronauts    4.77
# Chefs         4.23
# Name: num_sentences, dtype: float64
#
# Maximum Number of Sentences per Category:
#  Category
# Astronauts    26
# Chefs         49
# Name: num_sentences, dtype: int64

# %% [markdown]
# - Box plots for both categories

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=biographies_df, x='Category', y='num_sentences')
plt.title('Box Plot of Number of Sentences per Category')
plt.xlabel('Category')
plt.ylabel('Number of Sentences')
plt.show()

# %% [markdown]
# - Box Plot of Number of Sentences for 'Astronauts'
# - Box Plot of Number of Sentences for 'Chefs'

# %%
categories = biographies_df['Category'].unique()

for category in categories:
    plt.figure(figsize=(8, 4))

    data = biographies_df[biographies_df['Category'] == category]['num_sentences']

    plt.boxplot(data)

    plt.title(f'Box Plot of Number of Sentences for Category: {category}')
    plt.ylabel('Number of Sentences')

    plt.show()

# %% [markdown]
# - Histogram of Number of Sentences for both categories

# %%
plt.figure(figsize=(8, 4))

#for each category
for category in biographies_df['Category'].unique():
    data = biographies_df[biographies_df['Category'] == category]['num_sentences']
    plt.hist(data, bins=20, alpha=0.5, label=category, density=True)

plt.title('Histogram of Number of Sentences per Category')
plt.xlabel('Number of Sentences')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
#  - Histogram of Number of Sentences for 'Astronauts'
#  - Histogram of Number of Sentences for 'Chefs'

# %%
categories = biographies_df['Category'].unique()
for category in categories:
    plt.figure(figsize=(8, 4))
    data = biographies_df[biographies_df['Category'] == category]['num_sentences']
    plt.hist(data, bins=20, alpha=0.5)
    plt.title(f'Histogram of Number of Sentences for Category: {category}')
    plt.xlabel('Number of Sentences')
    plt.ylabel('Frequency')
    plt.show()

# %%
def collect_bigrams(tokens):
    bigrams = nltk.bigrams(tokens)
    occurences = {}
    for bigram in bigrams:
        if occurences.get(bigram):
            occurences[bigram] += 1
        else:
            occurences[bigram] = 1
    return occurences

# %%
bigrams1 = collect_bigrams(tokens1)
bigrams2 = collect_bigrams(tokens2)

# %%
bi_gram_counts = biographies_df['bi_grams'].apply(Counter)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bi_grams'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-46567eabccda> in <cell line: 1>()
# ----> 1 bi_gram_counts = biographies_df['bi_grams'].apply(Counter)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'bi_grams'

# %% [markdown]
# - bi_gram counts for each category

# %%
bi_gram_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-999b90e41a88> in <cell line: 1>()
# ----> 1 bi_gram_counts
#
# NameError: name 'bi_gram_counts' is not defined

# %%
total_bi_gram_counts = biographies_df.groupby('Category')['bi_gram_counts'].apply(lambda x: sum(x, Counter()))
print("Total number of bi-gram occurrences per category:")
print(total_bi_gram_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-53f32abce913> in <cell line: 1>()
# ----> 1 total_bi_gram_counts = biographies_df.groupby('Category')['bi_gram_counts'].apply(lambda x: sum(x, Counter()))
#       2 print("Total number of bi-gram occurrences per category:")
#       3 print(total_bi_gram_counts)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1769                 "Use a list instead."
#    1770             )
# -> 1771         return super().__getitem__(key)
#    1772
#    1773     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
#     246             return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: bi_gram_counts'

# %% [markdown]
# - min/max/avg number of bi-gram occurrences per sentence per category.

# %%
min_per_category = biographies_df.groupby('Category')['bi_grams'].apply(lambda x: np.min([len(bi_gram) for bi_gram in x]))
max_per_category = biographies_df.groupby('Category')['bi_grams'].apply(lambda x: np.max([len(bi_gram) for bi_gram in x]))
avg_per_category = biographies_df.groupby('Category')['bi_grams'].apply(lambda x: np.mean([len(bi_gram) for bi_gram in x]))

print("\nMin number of bi-gram occurrences per sentence per category:")
print(min_per_category)

print("\nMax number of bi-gram occurrences per sentence per category:")
print(max_per_category)

print("\nAverage number of bi-gram occurrences per sentence per category:")
print(avg_per_category)
# Out:
# Min number of bi-gram occurrences per sentence per category:
# Category
# Astronauts    6
# Chefs         3
# Name: bi_grams, dtype: int64
#
# Max number of bi-gram occurrences per sentence per category:
# Category
# Astronauts    311
# Chefs         526
# Name: bi_grams, dtype: int64
#
# Average number of bi-gram occurrences per sentence per category:
# Category
# Astronauts    48.78
# Chefs         43.32
# Name: bi_grams, dtype: float64

# %% [markdown]
# Q2. Named Entity Recognition: analysis by entity type

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Using cached stanza-1.8.2-py3-none-any.whl (990 kB)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from stanza) (2.12.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.25.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.3.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (12.1.105)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (10.3.2.106)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3.0->stanza) (12.5.40)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Installing collected packages: nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
# Successfully installed nvidia-cudnn-cu12-8.9.2.26 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 stanza-1.8.2

# %%
import stanza.pipeline
stanza.download('en')
nlp_stanza = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma,ner')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: en (English) ...
# INFO:stanza:File exists: /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# =========================================
# | Processor | Package                   |
# -----------------------------------------
# | tokenize  | combined                  |
# | mwt       | combined                  |
# | pos       | combined_charlm           |
# | lemma     | combined_nocharlm         |
# | ner       | ontonotes-ww-multi_charlm |
# =========================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
import matplotlib.pyplot as plt
import spacy
import stanza
nlp_spacy = spacy.load("en_core_web_sm")

# %% [markdown]
# * Writing a function that checks a biography for the tokens
#
# 1.   Checks the number of spans where there is complete overlap
#
# 2.   Partial overlap in spans predicted
# 3. Number of spans a package predicted as an NE, but other package did not
# 4. Spans with full and partial agreement

# %%
import spacy
import stanza
import pandas as pd
import matplotlib.pyplot as plt


def check_biography(biography):
    """
    Checks a biography for named entity recognition agreement between spaCy and Stanza.

    Args:
        biography (str): The biography to check.

    Returns:
        dict: A dictionary containing the following information:
            - full_agreement: Number of spans with complete overlap in predicted NE.
            - partial_agreement: Number of spans with partial overlap in predicted NE.
            - spacy_only: Number of spans predicted as NE only by spaCy.
            - stanza_only: Number of spans predicted as NE only by Stanza.
            - type_agreement: Number of spans with agreement in NE type.
    """

    # Process the biography with spaCy and Stanza
    doc_spacy = nlp_spacy(biography)
    doc_stanza = nlp_stanza(biography)

    # Initialize counters
    full_agreement = 0
    partial_agreement = 0
    spacy_only = 0
    stanza_only = 0
    type_agreement = 0

    spacy_entities = [(ent.start, ent.end, ent.label_) for ent in doc_spacy.ents]
    stanza_entities = [(ent.start_char, ent.end_char, ent.type) for ent in doc_stanza.ents]

    # Iterate over the spaCy spans
    for span_spacy in spacy_entities:
        full_overlap = False
        partial_overlap = False
        for span_stanza in stanza_entities:

            # Full agreement
            if span_spacy[0] == span_stanza[0] and span_spacy[1] == span_stanza[1]:
                full_agreement += 1
                full_overlap = True

                # Check for type agreement
                if span_spacy[2] == span_stanza[2]:
                    type_agreement += 1
                    type_overlap = True
                break

            # Partial agreement
            elif (span_stanza[0] <= span_spacy[0] <= span_stanza[1]) or (span_stanza[0] <= span_spacy[1] <= span_stanza[1]):
                partial_agreement += 1

                break

        if not full_overlap and not partial_overlap:
            spacy_only += 1

    # Count Stanza-only spans
    for span_stanza in stanza_entities:
        if not any((span_stanza[0] <= span[0] <= span_stanza[1]) or (span_stanza[0] <= span[1] <= span_stanza[1]) for span in spacy_entities):
            stanza_only += 1

    return {
        "full_agreement": full_agreement,
        "partial_agreement": partial_agreement,
        "spacy_only": spacy_only,
        "stanza_only": stanza_only,
        "type_agreement": type_agreement,
    }
#Iterating through the biographies to obtain the results
biographies_astronauts = df[df["Category"] == "Astronauts"]["Biography"].tolist()
biographies_chefs = df[df["Category"] == "Chefs"]["Biography"].tolist()

results_astronauts = [check_biography(biography) for biography in biographies_astronauts]
results_chefs = [check_biography(biography) for biography in biographies_chefs]

# %% [markdown]
# * Agregating the results for Spacy and Stanza

# %%
def aggregate_results(results):
    """
    Aggregates the results from multiple biography checks.

    Args:
        results (list): A list of dictionaries containing the results from each biography check.

    Returns:
        dict: A dictionary containing the aggregated results.
    """
    aggregated = {
        "full_agreement": sum(result["full_agreement"] for result in results),
        "partial_agreement": sum(result["partial_agreement"] for result in results),
        "spacy_only": sum(result["spacy_only"] for result in results),
        "stanza_only": sum(result["stanza_only"] for result in results),
        "type_agreement": sum(result["type_agreement"] for result in results),
    }
    return aggregated

agg_results_astronauts = aggregate_results(results_astronauts)
agg_results_chefs = aggregate_results(results_chefs)
print(agg_results_astronauts)
print(agg_results_chefs)
# Out:
# {'full_agreement': 0, 'partial_agreement': 3, 'spacy_only': 1, 'stanza_only': 2, 'type_agreement': 0}
# {'full_agreement': 0, 'partial_agreement': 1, 'spacy_only': 1, 'stanza_only': 2, 'type_agreement': 0}

# %% [markdown]
# * 5. Visualising the results

# %%
# Prepare data for plotting
categories = ["Astronauts", "Chefs"]
metrics = ["full_agreement", "partial_agreement", "spacy_only", "stanza_only", "type_agreement"]

data = {
    "Astronauts": agg_results_astronauts,
    "Chefs": agg_results_chefs
}

# Plotting the results
fig, ax = plt.subplots(figsize=(10, 6))

x = range(len(metrics))
width = 0.35

ax.bar(x, [data["Astronauts"][metric] for metric in metrics], width, label="Astronauts")
ax.bar([p + width for p in x], [data["Chefs"][metric] for metric in metrics], width, label="Chefs")

ax.set_xlabel('Metrics')
ax.set_ylabel('Counts')
ax.set_title('NER Agreement Metrics for Astronauts and Chefs')
ax.set_xticks([p + width / 2 for p in x])
ax.set_xticklabels(metrics)
ax.legend()

plt.show()

# %% [markdown]
# Q3. NER: Verification against Knowledge Graph

# %% [markdown]
# *   Writing a function that checks:
# 1. How many NE's predicted by Stanza & Spacy can be found mentioned in the KG Graph

# %% [markdown]
# * The ratio of predicted NE's that can be confidently said to be in the KG graph
